# %%
import pandas as pd
import numpy as np
from doc_bd import Manage_db
import json
import os
import mysql.connector
from mysql.connector import errorcode
import re
import urllib3 
import time
import warnings
warnings.filterwarnings('ignore')
urllib3.disable_warnings()
import matplotlib.pyplot as plt
from pymongo import MongoClient
#import sklearn

# %%
sql = Manage_db(database = 'lop2test', host = 'localhost', user='root', password='')

client = MongoClient("localhost", 27017)
db = client['lop2test']
submissions_lop = db['submissions']

#df_class.loc[df['id_class'] == 'f2dd7bef-5b5d-4cb3-9efa-aa8652af0605']
id_class = 'e378c59f-e815-4a41-95fc-e95e4432a34c'
#pd_data = pd.DataFrame([id_class], columns = ['id_class'])
condition = "WHERE class_id = 'e378c59f-e815-4a41-95fc-e95e4432a34c'"
df_submission = sql.search(table='submission')
list_quest_subm = df_submission.drop(['ip', 'id', 'environment','hitPercentage','timeConsuming','createdAt','type','language', 'answer', 'char_change_number', 'user_id', 'lesson_id', 'class_id', 'test_id'], axis=1).drop_duplicates()
df_submission_class = sql.search(table='submission', condition=condition)
df_lop_lists = sql.search(table='listQuestions')

df_lop_tests = sql.search(table='test')

df_class = sql.search(table='class')
df_quest = sql.search(table='question')

users_class = sql.search(table='classHasUser')
tag = sql.search(table='tag')
quest_tag = sql.search(table='questionHasTag')
df_list_q = sql.search(table='listHasQuestion')

# %%
tag.columns.values[0] ='tag_id'
list_class = df_submission_class['listQuestions_id'].drop_duplicates().reset_index(name='id')
a = df_lop_lists.columns.tolist()
df_list_class = pd.DataFrame(columns = a)

for i in range(list_class.count().values[0]):
    for a in range(df_lop_lists.count().values[0]):
        if list_class['id'][i] == df_lop_lists['id'][a]:
            b = dict(df_lop_lists.loc[a])
            df_list_class = df_list_class.append(b, ignore_index=True)
df_list_class.columns.values[0] = 'listQuestions_id'

test_class = df_submission_class['test_id'].drop_duplicates().reset_index(name='id')
a = df_lop_tests.columns.tolist()
df_test_class = pd.DataFrame(columns = a)

for i in range(test_class.count().values[0]):
    for a in range(df_lop_tests.count().values[0]):
        if test_class['id'][i] == df_lop_tests['id'][a]:
            b = dict(df_lop_tests.loc[a])
            df_test_class = df_test_class.append(b, ignore_index=True)
df_test_class.columns.values[0] = 'test_id'

quest_class = df_submission_class['question_id'].drop_duplicates().reset_index(name='id')
a = df_quest.columns.tolist()
df_quest_class = pd.DataFrame(columns = a)

for i in range(quest_class.count().values[0]):
    for a in range(df_quest.count().values[0]):
        if quest_class['id'][i] == df_quest['id'][a]:
            b = dict(df_quest.loc[a])
            df_quest_class = df_quest_class.append(b, ignore_index=True)
df_quest_class.columns.values[0] = 'question_id'

#verificando o total de questoes cadastrados em listas da turma 
list_name = df_list_class['listQuestions_id'].tolist()
a = df_list_q.columns.tolist()
df_q_l = pd.DataFrame(columns = a)

for i in range(df_list_class.count().values[0]):
    for a in range(df_list_q.count().values[0]):
        if df_list_class['listQuestions_id'][i] == df_list_q['list_id'][a]:
            b = dict(df_list_q.loc[a])
            df_q_l = df_q_l.append(b, ignore_index=True)

subs =[]
for x in submissions_lop.find():
    subs.append(x)
df_class_lop = pd.DataFrame(subs)

# %%
list_class = df_class_lop['listQuestions_id'].drop_duplicates().reset_index(name='id')
a = df_lop_lists.columns.tolist()
df_list_lop = pd.DataFrame(columns = a)

for i in range(list_class.count().values[0]):
    for a in range(df_lop_lists.count().values[0]):
        if list_class['id'][i] == df_lop_lists['id'][a]:
            b = dict(df_lop_lists.loc[a])
            df_list_lop = df_list_lop.append(b, ignore_index=True)
df_list_lop.columns.values[0] = 'listQuestions_id'
df_list_lop
# Out:
#                         listQuestions_id  \
# 0   9338cc7b-7cf4-4d9f-af63-25a7effa7189
# 1   dd1cd083-6c00-4605-9ff1-163bd4069363
# 2   aca84206-87b2-4478-afa4-6193119cc06a
# 3   c6f3f5e5-0b0c-4396-92ba-d22d4125f555
# 4   813dedaa-0989-489b-9804-3850ae4b83d1
# 5   f5bc770d-2ac7-4060-ab1c-e42b5541f7a7
# 6   5ebe517f-50f2-4629-a22f-1dea895fce25
# 7   1551e3ed-c875-4bb3-8e4e-58407df40776
# 8   cf509a46-6a97-440e-a5c0-f7ba7537ef96
# 9   e1f0e8be-54fe-4b54-8d6d-2451bedc0647
# 10  102050fa-c902-4258-a988-01dad84ff63f
# 11  cf81af12-b0b7-40c2-8536-5e7445ace7a3
# 12  0a2c49a2-482c-40d7-bc44-ee368f089560
# 13  c4d09d1b-73a5-45c6-8a0d-ead669114b65
# 14  93cd33c4-109a-401e-87e9-e26ff5929d37
# 15  34691c68-f01d-46ad-808d-6bbd44bcd9a2
# 16  3ab11cee-77d1-4448-9587-880929570cf3
# 17  70e6c800-7583-485d-ac9f-9c42c48dd785
# 18  f5b1d992-68de-4854-97d8-c4bd84bd593b
# 19  70d1aa7e-00cb-4428-892f-9ac67cc50449
# 20  42d5c4ad-7b44-4e4e-b2e5-2997785132c8
# 21  dbfcc83c-f014-44ae-8260-f06d4e1370ba
# 22  4f3452ae-87d4-4a5f-9532-c7634da2cff0
# 23  9bfe2a0b-120f-4df7-a3f7-89a8e100b0b1
# 24  bd91406e-0a5a-4d22-8e7d-f61a4352b509
#
#                                                 title        code  \
# 0    (Lop) Estruturas de decisão - Múltiplas decisões  358922cf78
# 1       Repetição condicional - Lista Resolvida (LOP)  f00e8a3272
# 2   Repetição condicional - Lista de Exercícios (LOP)  0814ea8f94
# 3             Laboratório 01 - Expressões Aritméticas  d0947edaac
# 4             Repetição contada - Lista Prática (LOP)  73a86e8081
# 5       Repetição contada - Lista de Exercícios (LOP)  7a2e23fcb3
# 6                          Aula - Funções Aritméticas  4749406f21
# 7                 Vetores - Lista de Exercícios (LOP)  309289819d
# 8   (Lop) Estruturas de decisão - problemas sobre ...  5c2cb0df7d
# 9                Treinamento - Expressões Aritméticas  87add2f05c
# 10          Aula - Introdução Expressões Aritiméticas  3466d508bd
# 11   (Lop) Estruturas de decisão - Operadores Lógicos  6453a7da1d
# 12        Repetição condicional - Lista Prática (LOP)  5dc5d4f372
# 13                      Vetores - Lista Prática (LOP)  95938010fe
# 14                    Vetores - Lista Resolvida (LOP)  3c9087f448
# 15          Repetição contada - Lista Resolvida (LOP)  b04c721d7e
# 16  (Lop) Lista de Laboratório 2 - Estrutura de de...  5d418ccffa
# 17       Expressões Aritméticas - Lista Prática (LOP)  cdc3e08481
# 18  Estruturas de Decisão - Lista de Exercícios (LOP)  ff2b68042d
# 19        Estruturas de Decisão - Lista Prática (LOP)  2833e8080c
# 20  Expressões Aritméticas - Lista de Exercícios (...  07a925de2f
# 21      Estruturas de Decisão - Lista Resolvida (LOP)  f05a052fdd
# 22     Expressões Aritméticas - Lista Resolvida (LOP)  dbf8561c3d
# 23                             Variáveis e expressões  17ef64c684
# 24            Lab1_Variáveis, Constantes e Operadores  39a154d763
#
#              createdAt           updatedAt  \
# 0  2020-03-23 16:07:21 2020-09-15 00:03:03
# 1  2020-06-24 11:44:44 2020-06-24 13:30:49
# 2  2020-06-29 12:19:48 2020-06-29 12:19:48
# 3  2020-02-28 14:49:23 2020-02-28 14:49:23
# 4  2020-07-07 11:56:51 2020-07-07 11:56:51
# 5  2020-07-07 11:59:39 2020-07-07 11:59:39
# 6  2020-03-04 21:55:18 2020-03-04 21:55:18
# 7  2020-07-16 17:37:42 2020-07-16 17:37:42
# 8  2020-04-08 01:15:40 2020-04-08 01:15:40
# 9  2020-03-06 16:09:41 2020-03-06 16:09:41
# 10 2020-02-28 20:41:17 2020-02-28 20:41:17
# 11 2020-04-04 01:47:59 2020-09-15 00:02:40
# 12 2020-06-24 13:11:49 2020-06-24 13:30:28
# 13 2020-07-17 02:34:58 2020-07-17 02:34:58
# 14 2020-07-16 00:56:16 2020-07-16 00:56:16
# 15 2020-07-06 13:55:27 2020-07-08 20:35:54
# 16 2020-03-12 13:40:16 2020-03-12 13:40:16
# 17 2021-01-20 17:19:29 2021-01-20 17:19:29
# 18 2021-01-29 20:31:17 2021-01-29 20:31:17
# 19 2021-01-29 20:21:51 2021-01-29 20:21:51
# 20 2021-01-20 17:26:24 2021-01-20 17:26:24
# 21 2021-01-29 20:16:08 2021-02-01 13:32:47
# 22 2021-01-20 17:01:26 2021-02-01 13:32:32
# 23 2020-03-04 13:23:54 2020-03-04 13:23:54
# 24 2020-03-06 14:08:48 2020-03-06 14:08:48
#
#                                author_id
# 0   1a3aa181-9fc6-41e1-b61a-febd18f4eb23
# 1   2985b749-e081-400c-b2cc-97ae042a777d
# 2   2985b749-e081-400c-b2cc-97ae042a777d
# 3   1a3aa181-9fc6-41e1-b61a-febd18f4eb23
# 4   02673ba8-1fcb-4cb0-9cf3-a789cab48731
# 5   02673ba8-1fcb-4cb0-9cf3-a789cab48731
# 6   1a3aa181-9fc6-41e1-b61a-febd18f4eb23
# 7   6a36fa60-665f-4d15-a9de-0a523b93ca71
# 8                                   None
# 9   1a3aa181-9fc6-41e1-b61a-febd18f4eb23
# 10  1a3aa181-9fc6-41e1-b61a-febd18f4eb23
# 11  1a3aa181-9fc6-41e1-b61a-febd18f4eb23
# 12  2985b749-e081-400c-b2cc-97ae042a777d
# 13  9ed18ab4-989f-4905-b26a-84f647688ea2
# 14  9ed18ab4-989f-4905-b26a-84f647688ea2
# 15  2985b749-e081-400c-b2cc-97ae042a777d
# 16  1a3aa181-9fc6-41e1-b61a-febd18f4eb23
# 17  02673ba8-1fcb-4cb0-9cf3-a789cab48731
# 18  02673ba8-1fcb-4cb0-9cf3-a789cab48731
# 19  02673ba8-1fcb-4cb0-9cf3-a789cab48731
# 20  02673ba8-1fcb-4cb0-9cf3-a789cab48731
# 21  02673ba8-1fcb-4cb0-9cf3-a789cab48731
# 22  02673ba8-1fcb-4cb0-9cf3-a789cab48731
# 23  1a3aa181-9fc6-41e1-b61a-febd18f4eb23
# 24  1a3aa181-9fc6-41e1-b61a-febd18f4eb23

# %%
#aprovados - acima da media
#submissoes da turma

#retirando da df_class_lop todas as turmas do 2020.1
l_classes = df_class_lop['class_id'].drop_duplicates().tolist()
nclasses = []
nclasses.append(l_classes[0])
nclasses.append(l_classes[5])
nclasses.append(l_classes[8])

df_class_lop = df_class_lop.drop( df_class_lop[df_class_lop['class_id']==nclasses[0]].index )
df_class_lop = df_class_lop.drop( df_class_lop[df_class_lop['class_id']==nclasses[1]].index )
df_class_lop = df_class_lop.drop( df_class_lop[df_class_lop['class_id']==nclasses[2]].index )

df_performance = df_class_lop.groupby(['class_id', 'user_id', 'listQuestions_id','question_id'])['hitPercentage'].max().reset_index()
#soma das notas por lista
df_performance = df_performance.groupby(['class_id', 'user_id','listQuestions_id'])['hitPercentage'].sum().reset_index()
#Me traz as porcentagens maximas de acerto por questão
df_performance = df_class_lop.groupby(['class_id', 'user_id','listQuestions_id','question_id'])['hitPercentage'].max().reset_index()
      #Soma as porcentagens de uma lista/prova unica
df_performance = df_performance.groupby(['class_id', 'user_id','listQuestions_id'])['hitPercentage'].sum().reset_index()
      #Renomeando para melhorar entendimento
df_performance.rename(columns={'hitPercentage':'totalHitPercentage'}, inplace = True)
#Listas cadastradas nessa turma
lists = df_class_lop['listQuestions_id'].drop_duplicates().values
#Lista de alunos
df_without_duplicates = df_class_lop.drop_duplicates(subset=['class_id', 'user_id'])
    #df_without_duplicates = df_without_duplicates[['user_id']]
df_prov = pd.DataFrame()
for lista in lists:
    df_users = df_without_duplicates.copy()
    df_users['listQuestions_id'] = lista
    df_prov = df_prov.append(df_users)
    #df_prov.loc[df_prov['user_id']=='Flávio']
df_performance = pd.merge(df_performance,df_prov, on=['class_id', 'user_id','listQuestions_id'], how='outer')#.fillna(0)  
    #df_question_data = df_quest.groupby(['listQuestions_id','question_id'])['id_list'].count().reset_index()
      #Conta quantas questões tem por lista
df_question_data = list_quest_subm.groupby(['listQuestions_id'])['question_id'].count().reset_index(name='totalQuestionslist')
      #Merge
df_performance = df_performance.merge(df_question_data, on = 'listQuestions_id')
    #Média de acerto por lista
df_performance['medialist'] = df_performance['totalHitPercentage'] / df_performance['totalQuestionslist']
      #Convertendo para datetime
df_lop_lists['createdAt'] = pd.to_datetime(df_lop_lists['createdAt'])
      #Criando campo com a data
df_lop_lists['dateList'] = df_lop_lists['createdAt'].dt.date
      #Merge
lists_df = df_list_lop
lists_df.columns.values[0] = 'listQuestions_id'

df_performance = pd.merge(df_performance, lists_df.drop(columns = ['createdAt']), on='listQuestions_id')
    #graph1
    #Número de alunos na turma
#total_students = df_class_lop.drop(['_id','timeInSecounds','question_id', 'listQuestions_id', 'id','environment','timeConsuming','createdAt','char_change_number', 'test_id', 'language', 'hitPercentage', 'ip', 'type', 'answer', 'lesson_id'], axis=1).drop_duplicates()
#total_students = total_students.groupby(['class_id'])['user_id'].count()
#total_students = total_students['user_id'].count()

    #Media por lista por cada turma
#df_mean_list = (df_performance.groupby(['listQuestions_id'])['medialist'].sum() / total_students).reset_index(name='mediaListClass')
#newDf = pd.merge(df_performance, df_mean_list,on=['listQuestions_id']).sort_values(by=['user_id']).drop(columns = ['mediaListClass','totalHitPercentage', 'listQuestions_id', 'totalQuestionslist']).fillna(0)
    #newDf.loc[newDf['user_id']=='Alexandre Leonardo']
newDf = df_performance
newDf = newDf.groupby(['user_id', 'class_id'])['medialist'].sum().reset_index()
newDf['medialist'] = newDf['medialist'] / lists_df.count().values[0]
    #newDf
    #newDf[newDf['medialist']>=50].values[0]
    #newDf['medialist'].values[0]
    #for a in range(newDf.count().values[0]):
    #    if newDf['medialist'].values[a]>=50:
    #        b=b+1
    #b
newDf['aprovado'] = 2
for a in range(newDf.count().values[0]):
    if newDf['medialist'].values[a]>=50:
        newDf['aprovado'][a]=1
    else:
        newDf['aprovado'][a]=0
newDf[newDf['aprovado']==1]
# Out:
#                                   user_id  \
# 1    01e8e5bd-3215-4276-9024-5ebc5a6897cf
# 2    025b0056-585f-485e-92e7-57a0c7854cce
# 5    0343690d-9edd-48cf-be09-6dc1f4b3f61c
# 6    035bbeb6-140b-413c-826d-9f92e36a31ae
# 8    047eb461-ce62-4eb4-bf0f-edea350f4873
# ..                                    ...
# 473  f69adfc6-de1e-406d-bd3d-9edf2e562ac8
# 477  f7817f2f-cd2e-424a-b085-0411dc4aa1d5
# 479  fb10ec34-7cf7-4ca7-910b-0cec1331b2b3
# 485  fe3c3b36-a1ab-4365-b088-1686cd5177d0
# 486  fe56d94c-26d1-4e75-85d1-0b10a07ece8b
#
#                                  class_id  medialist  aprovado
# 1    f7144f91-f493-4e55-aac5-39f0d4add995  57.357704         1
# 2    8f055c33-00ad-4284-aec8-da401901e795  50.177404         1
# 5    8394d1cb-86b5-4b90-bc62-4b9b192a81f6  56.126984         1
# 6    8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1
# 8    8f055c33-00ad-4284-aec8-da401901e795  58.984127         1
# ..                                    ...        ...       ...
# 473  e9c7c378-eac4-44b2-b687-4dca6d77cd54  57.188043         1
# 477  8f055c33-00ad-4284-aec8-da401901e795  56.154995         1
# 479  8f055c33-00ad-4284-aec8-da401901e795  58.984127         1
# 485  d99923f0-d174-4902-9759-c8220b821d36  54.240896         1
# 486  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  53.301587         1
#
# [221 rows x 4 columns]

# %%
#tem algo aqui dando erro
df_class_lop_t = df_class_lop.sort_values('createdAt')
name_class = df_class_lop_t['class_id'].iloc[0]
one_class = df_class_lop_t[df_class_lop_t['class_id']==name_class]
order_lists = one_class['listQuestions_id'].drop_duplicates().tolist()
users = one_class['user_id'].drop_duplicates().tolist()
usersp = one_class.groupby(['user_id'])['listQuestions_id'].count().reset_index(name='ateLista')
usersp['user_id']=users
usersp['ateLista'] = 0

#for x in range(len(users)):
#    a=len(order_lists)
#    while a!=0:
#        one_studt = one_class[one_class['user_id']==users[x]]
#        qtd_subm = one_studt[one_studt['listQuestions_id']==order_lists[a-1]]
#        qtd_subm = qtd_subm.count().values[0]
#        if qtd_subm == 0:
#            a=a-1
#        else:
#            usersp['ateLista'][x] = (a)
#            break
#usersp

#z = ['user_id','l1', 'l2','l3','l4','l5','l6','l7','l8','l9','l10','l11','l12','l13','l14','l15','l16']
#listas_f = pd.DataFrame(columns = z)

#one_studt = one_class[one_class['user_id']==users[0]]
#list_a = one_studt['listQuestions_id'].drop_duplicates().tolist()
#teste = []
#b = len(list_a)-1
#for x in range(len(order_lists)):
#    for a in range(len(list_a)):
#        if order_lists[x] == list_a[a]:
#            teste.append(1)
#            break
#        elif a==b:
#            teste.append(0)
#teste
    #one_studt['listQuestions_id'].drop_duplicates().tolist()
    #te = df_class_lop_t[df_class_lop_t['user_id']=='05c35721-051a-43fa-96b7-aeec0d0eafb5']
    #te['listQuestions_id'].drop_duplicates().tolist()
    
    
lista_ate = []
for x in range(len(users)):
    one_studt = one_class[one_class['user_id']==users[x]]
    qtd_ate_l0 = one_studt['listQuestions_id'].drop_duplicates().tolist()
#    qtd_ate_l = qtd_ate_l0[len(qtd_ate_l0)-1]
    maior = 0
    for x in range(len(qtd_ate_l0)):
        for z in range(len(order_lists)):
            if qtd_ate_l0[x] == order_lists[z]:
                if maior < z:
                    maior = z
    lista_ate.append(maior)
#te = one_class[one_class['user_id']==usersp['user_id'].iloc[5]]
#te = te['listQuestions_id'].drop_duplicates()
#te = te.count()
#te
usersp['ateLista']=lista_ate

a = one_class[one_class['user_id']=='00ef5626-f029-49e8-aa27-1839357a55c0']
qtd_ate_l0 = a['listQuestions_id'].drop_duplicates().tolist()
qtd_ate_l = qtd_ate_l0[len(qtd_ate_l0)-1]
maior = 0
for x in range(len(qtd_ate_l0)):
    for z in range(len(order_lists)):
        if qtd_ate_l0[x] == order_lists[z]:
            if maior < z:
                maior = z
print(maior)
#usersp
usersp

#teste = one_class[one_class['user_id']=='00ef5626-f029-49e8-aa27-1839357a55c0']
#teste['listQuestions_id'].drop_duplicates()
#order_lists
# Out:
# 1
#                                  user_id  ateLista
# 0   337cb03d-871a-4e38-8ab1-f79f8a0d8807        15
# 1   ab916ff5-180e-401f-a1ff-de548e2d584d        15
# 2   dc04e57b-43e7-448a-8f4c-1b29fc696a8e        15
# 3   716464a3-83d7-41f6-afcd-bd5a77644c7f        15
# 4   00ef5626-f029-49e8-aa27-1839357a55c0         1
# ..                                   ...       ...
# 85  1afdd554-892d-4746-81ab-76809311b711        15
# 86  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f        15
# 87  bbf405b0-63d5-4031-9e5c-f4914a92c1dc        15
# 88  81c20d34-5d22-472d-8aac-7a215ce8296a        15
# 89  b9240348-c223-4c0d-b75f-09c522952143        15
#
# [90 rows x 2 columns]

# %%
qtd_ateLista = usersp.groupby(['ateLista'])['user_id'].count().reset_index(name='totalDeAlunosAteLista')
qtd_ateLista
#os alunos que estao cituados na lista 17 a fizeram e os que estão na 15, somente fizeram ate a 15, mas nao fizeram a 17. 
#aparentemente, somente os alunos que fizeram a questao 16, foram alguns ques submeteram na lista 17; mesma coisa pra lista 6 e 12
# Out:
#    ateLista  totalDeAlunosAteLista
# 0         0                      1
# 1         1                      1
# 2         2                      1
# 3         3                      1
# 4        14                      2
# 5        15                     84

# %%
qtd_totalAteLista = qtd_ateLista
for x in range(len(qtd_totalAteLista)):
    qtd_totalAteLista['totalDeAlunosAteLista'][x+1]= qtd_totalAteLista['totalDeAlunosAteLista'][x] + qtd_totalAteLista['totalDeAlunosAteLista'][x+1]
    if x==len(qtd_totalAteLista)-2:
        break
qtd_totalAteLista
#apagar ultima linha
# Out:
#    ateLista  totalDeAlunosAteLista
# 0         0                      1
# 1         1                      2
# 2         2                      3
# 3         3                      4
# 4        14                      6
# 5        15                     90

# %%
#talvez alguns alunos desistam nas ultimas listas por ja terem passado/aprendido e podem acharem que nao precisam a fazer
#verificar se ate em que momento há aluno que não submete nas ultimas e acaba passando
#quando houver um numero maior de reprovados que aprovados, para aqueles que somente fizeram ate tal lista: marcar até este periodo

# %%
aprovados1 = newDf[newDf['class_id']==name_class]
usersAteApr = pd.merge(aprovados1,usersp, on=['user_id'], how='outer')
usersAteApr
# Out:
#                                  user_id  \
# 0   00ef5626-f029-49e8-aa27-1839357a55c0
# 1   0343690d-9edd-48cf-be09-6dc1f4b3f61c
# 2   035bbeb6-140b-413c-826d-9f92e36a31ae
# 3   04a9f776-feee-4b63-8127-50270693e39f
# 4   05c35721-051a-43fa-96b7-aeec0d0eafb5
# ..                                   ...
# 85  e8af96e7-0bac-45ff-a498-f22acb1af407
# 86  ed3e0097-1441-41df-9e12-671039749c8e
# 87  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f
# 88  f5874924-7ed6-421c-ac14-3c0bccf51c24
# 89  fe56d94c-26d1-4e75-85d1-0b10a07ece8b
#
#                                 class_id  medialist  aprovado  ateLista
# 0   8394d1cb-86b5-4b90-bc62-4b9b192a81f6   8.000000         0         1
# 1   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  56.126984         1        15
# 2   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 3   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 4   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  56.126984         1        15
# ..                                   ...        ...       ...       ...
# 85  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 86  8394d1cb-86b5-4b90-bc62-4b9b192a81f6   8.333333         0         2
# 87  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 88  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  37.333333         0        15
# 89  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  53.301587         1        15
#
# [90 rows x 5 columns]

# %%
aprovs = usersAteApr[usersAteApr['aprovado']==1]
aprAlista = aprovs.groupby(['ateLista'])['aprovado'].count().reset_index(name='totalDeAprAteLista')
aprAlista
# Out:
#    ateLista  totalDeAprAteLista
# 0        14                   1
# 1        15                  51

# %%
ate_Lista = usersp.groupby(['ateLista'])['user_id'].count().reset_index(name='totalDeAlunosAteLista')
porcentAtePlista = usersp.groupby(['ateLista'])['user_id'].count().reset_index(name='totalDeAlunosAteLista')
porcentAtePlista['totalDeAlunosAteLista']=0.0
for x in range(len(ate_Lista)):
    for a in range(len(aprAlista)):
        if ate_Lista['ateLista'][x] == aprAlista['ateLista'][a]:
#            print(x)
            porcentAtePlista['totalDeAlunosAteLista'][x] = aprAlista['totalDeAprAteLista'][a] / ate_Lista['totalDeAlunosAteLista'][x]
#c = aprPlista['totalDeAprQtdLista'][2] / qtd_Lista['totalDeAlunosQtdLista'][13]
#c
porcentAtePlista
# Out:
#    ateLista  totalDeAlunosAteLista
# 0         0               0.000000
# 1         1               0.000000
# 2         2               0.000000
# 3         3               0.000000
# 4        14               0.500000
# 5        15               0.607143

# %%
user=df_class_lop[df_class_lop['user_id']=='4115a1c9-77f8-402b-be86-18acc8f13d6c']
user['listQuestions_id'].drop_duplicates().count()
# Out:
# 15

# %%
user = user.groupby(['listQuestions_id','question_id'])['hitPercentage'].max().reset_index()
user
# Out:
#                          listQuestions_id  \
# 0    0a2c49a2-482c-40d7-bc44-ee368f089560
# 1    0a2c49a2-482c-40d7-bc44-ee368f089560
# 2    0a2c49a2-482c-40d7-bc44-ee368f089560
# 3    0a2c49a2-482c-40d7-bc44-ee368f089560
# 4    0a2c49a2-482c-40d7-bc44-ee368f089560
# ..                                    ...
# 117  f5bc770d-2ac7-4060-ab1c-e42b5541f7a7
# 118  f5bc770d-2ac7-4060-ab1c-e42b5541f7a7
# 119  f5bc770d-2ac7-4060-ab1c-e42b5541f7a7
# 120  f5bc770d-2ac7-4060-ab1c-e42b5541f7a7
# 121  f5bc770d-2ac7-4060-ab1c-e42b5541f7a7
#
#                               question_id  hitPercentage
# 0    0bafadf5-560a-4335-a8ad-ac103c4506f8          100.0
# 1    24e8bcf3-c8c2-4da7-9509-b0a32ee92d26          100.0
# 2    7d3e769d-bb40-45cb-b7ff-00d84fd9038c          100.0
# 3    93bb5054-3e03-474e-b6ce-91e1a312e2b6          100.0
# 4    b30961ca-2439-424a-823a-47429b15502f          100.0
# ..                                    ...            ...
# 117  465c29d2-d975-40dd-ac8d-246b43a33535          100.0
# 118  46e5a4d1-6eb2-4808-a963-e45b8bbd34c1          100.0
# 119  cfe3be8b-6cbd-462c-b572-48f59c9958cb          100.0
# 120  d0f099fb-277a-4684-b9c9-38ff1116ef06          100.0
# 121  dfaa539b-270b-441b-a285-da8e2e4fa120          100.0
#
# [122 rows x 3 columns]

# %%
order_lists = one_class['listQuestions_id'].drop_duplicates().tolist()
#usersp = one_class.groupby(['listQuestions_id'])['user_id'].count().reset_index(name='ateLista')
#usersp['ateLista'] = 0
a=len(order_lists)
#while a!=0:
#    one_studt = df_class_lop[df_class_lop['user_id']=='4115a1c9-77f8-402b-be86-18acc8f13d6c']
#    qtd_subm = one_studt[one_studt['listQuestions_id']==order_lists[a-1]]
#    qtd_subm = qtd_subm.count().values[0]
#    if qtd_subm == 0:
#        a=a-1
#    else:
#        usersp['ateLista'][x] = a
#    break
#usersp
one_studt = df_class_lop[df_class_lop['user_id']=='4115a1c9-77f8-402b-be86-18acc8f13d6c']
qtd_subm = one_studt[one_studt['listQuestions_id']==order_lists[14]]
qtd_subm.count().values[0]
# Out:
# 17

# %%
#salvando todas as submissoes em ordem temporal
df_class_lop_t = df_class_lop.sort_values('createdAt')
#pegando o id da class e salvando todas as suas submissoes
name_class = df_class_lop_t['class_id'].iloc[0]
one_class = df_class_lop_t[df_class_lop_t['class_id']==name_class]
#pegando as listas da turma em ordem
order_lists = one_class['listQuestions_id'].drop_duplicates().tolist()
#pegando a lista de alunos que submeteram questoes
users = one_class['user_id'].drop_duplicates().tolist()
#salavndo a quantidade de listas que cada aluno resolveu
usersQtd = one_class.groupby(['user_id','listQuestions_id'])['question_id'].count().reset_index(name='qtdLista')
usersQtd = usersQtd.groupby(['user_id'])['listQuestions_id'].count().reset_index(name='qtdLista')
#usersp['ateLista'] = 0
#for x in range(len(users)):
#    a=len(order_lists)
#    while a!=0:
#        one_studt = one_class[one_class['user_id']==users[x]]
#        qtd_subm = one_studt[one_studt['listQuestions_id']==order_lists[a-1]]
#        qtd_subm = qtd_subm.count().values[0]
#        if qtd_subm == 0:
#            a=a-1
#            continue
#        else:
#            usersp['ateLista'][x] = a
#            break
usersQtd
# Out:
#                                  user_id  qtdLista
# 0   00ef5626-f029-49e8-aa27-1839357a55c0         2
# 1   0343690d-9edd-48cf-be09-6dc1f4b3f61c        15
# 2   035bbeb6-140b-413c-826d-9f92e36a31ae        15
# 3   04a9f776-feee-4b63-8127-50270693e39f        15
# 4   05c35721-051a-43fa-96b7-aeec0d0eafb5        15
# ..                                   ...       ...
# 85  e8af96e7-0bac-45ff-a498-f22acb1af407        15
# 86  ed3e0097-1441-41df-9e12-671039749c8e         3
# 87  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f        15
# 88  f5874924-7ed6-421c-ac14-3c0bccf51c24        10
# 89  fe56d94c-26d1-4e75-85d1-0b10a07ece8b        15
#
# [90 rows x 2 columns]

# %%
qtd_Lista = usersQtd.groupby(['qtdLista'])['user_id'].count().reset_index(name='totalDeAlunosQtdLista')
qtd_Lista
# Out:
#     qtdLista  totalDeAlunosQtdLista
# 0          1                      2
# 1          2                      2
# 2          3                      1
# 3          4                      4
# 4          5                      1
# 5          6                      1
# 6          7                      1
# 7          9                      3
# 8         10                      2
# 9         11                      3
# 10        12                      7
# 11        13                      5
# 12        14                      8
# 13        15                     50

# %%
aprovados1 = newDf[newDf['class_id']==df_class_lop_t['class_id'].iloc[0]]
porc_qtd_Lista = usersQtd.groupby(['qtdLista'])['user_id'].count().reset_index(name='totalDeAlunosQtdLista')
for a in range(len(qtd_Lista)):
    atual = usersQtd[usersQtd['qtdLista']==a+1]
    print(atual)
    cont=0
    total=atual.count().values[0]
    for x in range(total):
        verif_user=aprovados1[aprovados1['user_id']==atual['user_id'].iloc[x]]
        if verif_user['aprovado'].values[0]==1:
            cont=cont+1
#    porc_qtd_Lista['totalDeAlunosQtdLista'][a]= (cont/total)
#    print(total)
#    if a==len(qtd_totalAteLista)-1:
#        break
#atual = usersQtd[usersQtd['qtdLista']==15]
#total=atual.count().values[0]
#verif_user=aprovados1[aprovados1['user_id']==atual['user_id'].iloc[0]]
#aprov = verif_user['aprovado'].values[0]
#porc_qtd_Lista
# Out:
#                                  user_id  qtdLista
# 7   0d327166-a647-4fa2-8def-1a64f55b223c         1
# 73  c206e495-e2a7-4fad-8cc1-eed9690dc6dc         1
#                                  user_id  qtdLista
# 0   00ef5626-f029-49e8-aa27-1839357a55c0         2
# 14  1a3aa181-9fc6-41e1-b61a-febd18f4eb23         2
#                                  user_id  qtdLista
# 86  ed3e0097-1441-41df-9e12-671039749c8e         3
#                                  user_id  qtdLista
# 18  1eb39a33-8898-4a33-a978-b1db76e94c88         4
# 19  22215fc7-7011-4e76-bc64-27605710145d         4
# 21  2d994fe7-d982-4870-b187-606862334830         4
# 81  da131b91-0126-41ca-9e6e-17dad2104ffd         4
#                                  user_id  qtdLista
# 26  35a86d2d-e321-4d35-997e-e908d5335bbe         5
#                                  user_id  qtdLista
# 69  b9240348-c223-4c0d-b75f-09c522952143         6
#                                  user_id  qtdLista
# 41  64cc36c5-4fcc-445a-b360-3a25c9783645         7
# Empty DataFrame
# Columns: [user_id, qtdLista]
# Index: []
#                                  user_id  qtdLista
# 20  230c55ef-88d5-4149-aad5-0696c4aa5df8         9
# 61  97b56b83-d8ef-406e-a875-6a0a7b107f9f         9
# 74  c44de1e4-1812-4155-a330-2f17d8bc9d23         9
#                                  user_id  qtdLista
# 63  9fd9e9db-c163-4c65-b216-2e227c7fa1c3        10
# 88  f5874924-7ed6-421c-ac14-3c0bccf51c24        10
#                                  user_id  qtdLista
# 9   105d68c3-d07d-4cc4-a706-f46d46c5101a        11
# 17  1d7ba1a4-4e54-44d6-a05c-c18a75817338        11
# 83  e665b54f-9a93-4e52-9e53-73f6e3853d4e        11
#                                  user_id  qtdLista
# 5   06bddeab-42f1-428a-88d1-adf096da3432        12
# 16  1b845da2-b2e0-4e16-af64-c6b8673d14d3        12
# 23  32211158-57e9-4f25-a366-c736e009a740        12
# 28  3c40d867-e80a-4447-8f2c-7b4f9b8cc272        12
# 31  43dd8e83-481a-4abb-9773-f759d482affd        12
# 56  872865e3-6303-4b28-bd84-489d7e9111f6        12
# 79  d607a214-c9d6-4771-b3a9-3bc13a2d48a6        12
#                                  user_id  qtdLista
# 32  46401a6b-f8a0-4aae-8298-433848a09bd0        13
# 39  6055380e-fafa-4dcb-b6db-34fcd0843098        13
# 57  8b8abf76-bef9-4d7f-a0e8-afead692300e        13
# 64  a0c65c61-ade0-45ca-b8f3-8b3c6a0c2331        13
# 67  abed98d7-b206-4eaf-a6e6-aa604bf881c6        13
#                                  user_id  qtdLista
# 10  12dcea94-7fab-4488-a626-b64cdb0d6465        14
# 22  2e92504e-18aa-4a44-8644-5ea8aff4e216        14
# 27  39e453df-48f1-4988-b552-60c96fc67c4e        14
# 33  4d1c93d8-27fe-4dd5-abe0-09021ea31291        14
# 40  61378206-cf75-4fc0-95dc-43f6e81a788c        14
# 46  72290901-a9f2-490b-8c0d-32f90be1b1f7        14
# 70  bafe35cc-ce7e-484a-b496-6dcf0f99167e        14
# 82  dc04e57b-43e7-448a-8f4c-1b29fc696a8e        14

# %%
aprovados1 = newDf[newDf['class_id']==name_class]
usersQtdApr = pd.merge(aprovados1,usersQtd, on=['user_id'], how='outer')
usersQtdApr
# Out:
#                                  user_id  \
# 0   00ef5626-f029-49e8-aa27-1839357a55c0
# 1   0343690d-9edd-48cf-be09-6dc1f4b3f61c
# 2   035bbeb6-140b-413c-826d-9f92e36a31ae
# 3   04a9f776-feee-4b63-8127-50270693e39f
# 4   05c35721-051a-43fa-96b7-aeec0d0eafb5
# ..                                   ...
# 85  e8af96e7-0bac-45ff-a498-f22acb1af407
# 86  ed3e0097-1441-41df-9e12-671039749c8e
# 87  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f
# 88  f5874924-7ed6-421c-ac14-3c0bccf51c24
# 89  fe56d94c-26d1-4e75-85d1-0b10a07ece8b
#
#                                 class_id  medialist  aprovado  qtdLista
# 0   8394d1cb-86b5-4b90-bc62-4b9b192a81f6   8.000000         0         2
# 1   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  56.126984         1        15
# 2   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 3   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 4   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  56.126984         1        15
# ..                                   ...        ...       ...       ...
# 85  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 86  8394d1cb-86b5-4b90-bc62-4b9b192a81f6   8.333333         0         3
# 87  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 88  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  37.333333         0        10
# 89  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  53.301587         1        15
#
# [90 rows x 5 columns]

# %%
aprovs = usersQtdApr[usersQtdApr['aprovado']==1]
aprPlista = aprovs.groupby(['qtdLista'])['aprovado'].count().reset_index(name='totalDeAprQtdLista')
aprPlista
# Out:
#    qtdLista  totalDeAprQtdLista
# 0        13                   2
# 1        14                   3
# 2        15                  47

# %%
qtd_Lista = usersQtd.groupby(['qtdLista'])['user_id'].count().reset_index(name='totalDeAlunosQtdLista')
porcentAprPlista = usersQtd.groupby(['qtdLista'])['user_id'].count().reset_index(name='totalDeAlunosQtdLista')
porcentAprPlista['totalDeAlunosQtdLista']=0.0
for x in range(len(qtd_Lista)):
    for a in range(len(aprPlista)):
        if qtd_Lista['qtdLista'][x] == aprPlista['qtdLista'][a]:
#            print(x)
            porcentAprPlista['totalDeAlunosQtdLista'][x] = aprPlista['totalDeAprQtdLista'][a] / qtd_Lista['totalDeAlunosQtdLista'][x]
#c = aprPlista['totalDeAprQtdLista'][2] / qtd_Lista['totalDeAlunosQtdLista'][13]
#c
porcentAprPlista
# Out:
#     qtdLista  totalDeAlunosQtdLista
# 0          1                  0.000
# 1          2                  0.000
# 2          3                  0.000
# 3          4                  0.000
# 4          5                  0.000
# 5          6                  0.000
# 6          7                  0.000
# 7          9                  0.000
# 8         10                  0.000
# 9         11                  0.000
# 10        12                  0.000
# 11        13                  0.400
# 12        14                  0.375
# 13        15                  0.940

# %%
qtd_ateLista = usersp.groupby(['ateLista'])['user_id'].count().reset_index(name='totalDeAlunosAteLista')

aprovados1 = newDf[newDf['class_id']==name_class]
usersQtdApr2 = pd.merge(aprovados1,usersp, on=['user_id'], how='outer')
usersQtdApr2
# Out:
#                                  user_id  \
# 0   00ef5626-f029-49e8-aa27-1839357a55c0
# 1   0343690d-9edd-48cf-be09-6dc1f4b3f61c
# 2   035bbeb6-140b-413c-826d-9f92e36a31ae
# 3   04a9f776-feee-4b63-8127-50270693e39f
# 4   05c35721-051a-43fa-96b7-aeec0d0eafb5
# ..                                   ...
# 85  e8af96e7-0bac-45ff-a498-f22acb1af407
# 86  ed3e0097-1441-41df-9e12-671039749c8e
# 87  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f
# 88  f5874924-7ed6-421c-ac14-3c0bccf51c24
# 89  fe56d94c-26d1-4e75-85d1-0b10a07ece8b
#
#                                 class_id  medialist  aprovado  ateLista
# 0   8394d1cb-86b5-4b90-bc62-4b9b192a81f6   8.000000         0         1
# 1   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  56.126984         1        15
# 2   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 3   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 4   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  56.126984         1        15
# ..                                   ...        ...       ...       ...
# 85  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 86  8394d1cb-86b5-4b90-bc62-4b9b192a81f6   8.333333         0         2
# 87  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 88  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  37.333333         0        15
# 89  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  53.301587         1        15
#
# [90 rows x 5 columns]

# %%
qtd_ate = pd.merge(usersQtd,usersp, on=['user_id'], how='outer')
usersQtdAte = pd.merge(aprovados1,qtd_ate, on=['user_id'], how='outer')
usersQtdAte
# Out:
#                                  user_id  \
# 0   00ef5626-f029-49e8-aa27-1839357a55c0
# 1   0343690d-9edd-48cf-be09-6dc1f4b3f61c
# 2   035bbeb6-140b-413c-826d-9f92e36a31ae
# 3   04a9f776-feee-4b63-8127-50270693e39f
# 4   05c35721-051a-43fa-96b7-aeec0d0eafb5
# ..                                   ...
# 85  e8af96e7-0bac-45ff-a498-f22acb1af407
# 86  ed3e0097-1441-41df-9e12-671039749c8e
# 87  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f
# 88  f5874924-7ed6-421c-ac14-3c0bccf51c24
# 89  fe56d94c-26d1-4e75-85d1-0b10a07ece8b
#
#                                 class_id  medialist  aprovado  qtdLista  \
# 0   8394d1cb-86b5-4b90-bc62-4b9b192a81f6   8.000000         0         2
# 1   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  56.126984         1        15
# 2   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 3   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 4   8394d1cb-86b5-4b90-bc62-4b9b192a81f6  56.126984         1        15
# ..                                   ...        ...       ...       ...
# 85  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 86  8394d1cb-86b5-4b90-bc62-4b9b192a81f6   8.333333         0         3
# 87  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  58.984127         1        15
# 88  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  37.333333         0        10
# 89  8394d1cb-86b5-4b90-bc62-4b9b192a81f6  53.301587         1        15
#
#     ateLista
# 0          1
# 1         15
# 2         15
# 3         15
# 4         15
# ..       ...
# 85        15
# 86         2
# 87        15
# 88        15
# 89        15
#
# [90 rows x 6 columns]

# %%
porcentAtePlista
# Out:
#    ateLista  totalDeAlunosAteLista
# 0         0               0.000000
# 1         1               0.000000
# 2         2               0.000000
# 3         3               0.000000
# 4        14               0.500000
# 5        15               0.607143

# %%
#pode-se verificar a media de submissao POR QUESTAO FEITA para verificar os indices de evasão

# %%
#contando o erro por questao acima do tempo zero para prevenir duplo clicke. geralmente, se há cola ou algum problema relacionado, acaba nao sendo um erro na questao
#buscando erros por lista, por aluno
name_class = '8394d1cb-86b5-4b90-bc62-4b9b192a81f6'
one_class = df_class_lop[df_class_lop['class_id']==name_class]

one_class['timeInSecounds'] = one_class['timeConsuming'].divide(1000).astype(int)

df_without_duplicates = one_class[one_class["timeInSecounds"] > 0].drop(['language','class_id','test_id','environment','timeConsuming','createdAt','timeInSecounds','char_change_number', 'ip', 'type', 'answer', 'lesson_id', 'id'], axis=1)
df_erro = df_without_duplicates[df_without_duplicates["hitPercentage"] == 0]
df_erro = df_erro.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='totalError')
df_erro = df_erro.groupby(['user_id'])['totalError'].sum()

#buscando quantidade de questoes certas por lista por aluno
df_acerto = df_without_duplicates[df_without_duplicates["hitPercentage"] > 0]
df_acerto = df_acerto.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='totalAcert')
df_acerto = df_acerto.groupby(['user_id'])['totalAcert'].sum()

#buscando quantidade de questoes que com 100% de acerto por lista por aluno
df_100 = df_without_duplicates[df_without_duplicates["hitPercentage"] == 100].drop_duplicates()
df_100 = df_100.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='acert_100')
df_100 = df_100.groupby(['user_id'])['acert_100'].sum()

#buscar se o aluno chegou a tirar 100 na questão ou a nota final.
#há mais de um acerto, pois há mais vezes que tentam tirar mais que zero, mas nem sempre chegam no 100
#avaliar a possibilidade de colocar a nota maxima do aluno em coluna

df = pd.merge(df_erro, df_acerto, on=['user_id'], how='outer')
df = pd.merge(df, df_100, on=['user_id'], how='outer')
df.replace(np.NaN, 0, inplace = True)
df = pd.merge(df, newDf, on=['user_id']).drop('medialist', axis=1)
df
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 0   00ef5626-f029-49e8-aa27-1839357a55c0          47          16         16
# 1   0343690d-9edd-48cf-be09-6dc1f4b3f61c         217         284        158
# 2   035bbeb6-140b-413c-826d-9f92e36a31ae         198         235        133
# 3   04a9f776-feee-4b63-8127-50270693e39f         104         214        155
# 4   05c35721-051a-43fa-96b7-aeec0d0eafb5         535         379        197
# ..                                   ...         ...         ...        ...
# 90  e8af96e7-0bac-45ff-a498-f22acb1af407         387         316        136
# 91  ed3e0097-1441-41df-9e12-671039749c8e          21          16         16
# 92  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f         132         231        128
# 93  f5874924-7ed6-421c-ac14-3c0bccf51c24          67         117         87
# 94  fe56d94c-26d1-4e75-85d1-0b10a07ece8b         150         291        118
#
#                                 class_id  aprovado
# 0   8394d1cb-86b5-4b90-bc62-4b9b192a81f6         0
# 1   8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1
# 2   8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1
# 3   8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1
# 4   8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1
# ..                                   ...       ...
# 90  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1
# 91  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         0
# 92  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1
# 93  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         0
# 94  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1
#
# [95 rows x 6 columns]

# %%
a = df_without_duplicates.drop(['_id', 'hitPercentage', 'listQuestions_id'], axis=1).drop_duplicates()
qtd_qPa = a.groupby(['user_id'])['question_id'].count().reset_index(name='totalQuest')
media_df = pd.merge(df, qtd_qPa, on=['user_id'])
media_df['totalError'] = media_df['totalError'] / media_df['totalQuest']
media_df['totalAcert'] = media_df['totalAcert'] / media_df['totalQuest']
media_df['acert_100'] = media_df['acert_100'] / media_df['totalQuest']
media_df
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 0   00ef5626-f029-49e8-aa27-1839357a55c0    3.133333    1.066667   1.066667
# 1   0343690d-9edd-48cf-be09-6dc1f4b3f61c    1.808333    2.366667   1.316667
# 2   035bbeb6-140b-413c-826d-9f92e36a31ae    1.596774    1.895161   1.072581
# 3   04a9f776-feee-4b63-8127-50270693e39f    0.838710    1.725806   1.250000
# 4   05c35721-051a-43fa-96b7-aeec0d0eafb5    4.495798    3.184874   1.655462
# ..                                   ...         ...         ...        ...
# 90  e8af96e7-0bac-45ff-a498-f22acb1af407    3.120968    2.548387   1.096774
# 91  ed3e0097-1441-41df-9e12-671039749c8e    1.312500    1.000000   1.000000
# 92  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f    1.064516    1.862903   1.032258
# 93  f5874924-7ed6-421c-ac14-3c0bccf51c24    0.779070    1.360465   1.011628
# 94  fe56d94c-26d1-4e75-85d1-0b10a07ece8b    1.282051    2.487179   1.008547
#
#                                 class_id  aprovado  totalQuest
# 0   8394d1cb-86b5-4b90-bc62-4b9b192a81f6         0          15
# 1   8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1         120
# 2   8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1         124
# 3   8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1         124
# 4   8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1         119
# ..                                   ...       ...         ...
# 90  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1         124
# 91  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         0          16
# 92  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1         124
# 93  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         0          86
# 94  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1         117
#
# [95 rows x 7 columns]

# %%
df_cont_subm = df_without_duplicates.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='total_subm')
df_cont_subm = df_cont_subm.groupby(['user_id'])['total_subm'].sum()
media_df1 = pd.merge(df_cont_subm, qtd_qPa, on=['user_id'])
media_df1['total_subm'] = media_df1['total_subm'] / media_df1['totalQuest']
media_df1
# Out:
#                                  user_id  total_subm  totalQuest
# 0   00ef5626-f029-49e8-aa27-1839357a55c0    4.200000          15
# 1   0343690d-9edd-48cf-be09-6dc1f4b3f61c    4.175000         120
# 2   035bbeb6-140b-413c-826d-9f92e36a31ae    3.491935         124
# 3   04a9f776-feee-4b63-8127-50270693e39f    2.564516         124
# 4   05c35721-051a-43fa-96b7-aeec0d0eafb5    7.680672         119
# ..                                   ...         ...         ...
# 85  e8af96e7-0bac-45ff-a498-f22acb1af407    5.669355         124
# 86  ed3e0097-1441-41df-9e12-671039749c8e    2.312500          16
# 87  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f    2.927419         124
# 88  f5874924-7ed6-421c-ac14-3c0bccf51c24    2.139535          86
# 89  fe56d94c-26d1-4e75-85d1-0b10a07ece8b    3.769231         117
#
# [90 rows x 3 columns]

# %%
df_total = pd.merge(df_cont_subm, df, on=['user_id'])
prob_total = pd.merge(df_cont_subm, df, on=['user_id'])
prob_total['totalError'] = prob_total['totalError'] / prob_total['total_subm']
prob_total['totalAcert'] = prob_total['totalAcert'] / prob_total['total_subm']
prob_total['acert_100'] = prob_total['acert_100'] / prob_total['total_subm']
prob_total
# Out:
#                                  user_id  total_subm  totalError  totalAcert  \
# 0   00ef5626-f029-49e8-aa27-1839357a55c0          63    0.746032    0.253968
# 1   0343690d-9edd-48cf-be09-6dc1f4b3f61c         501    0.433134    0.566866
# 2   035bbeb6-140b-413c-826d-9f92e36a31ae         433    0.457275    0.542725
# 3   04a9f776-feee-4b63-8127-50270693e39f         318    0.327044    0.672956
# 4   05c35721-051a-43fa-96b7-aeec0d0eafb5         914    0.585339    0.414661
# ..                                   ...         ...         ...         ...
# 90  e8af96e7-0bac-45ff-a498-f22acb1af407         703    0.550498    0.449502
# 91  ed3e0097-1441-41df-9e12-671039749c8e          37    0.567568    0.432432
# 92  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f         363    0.363636    0.636364
# 93  f5874924-7ed6-421c-ac14-3c0bccf51c24         184    0.364130    0.635870
# 94  fe56d94c-26d1-4e75-85d1-0b10a07ece8b         441    0.340136    0.659864
#
#     acert_100                              class_id  aprovado
# 0    0.253968  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         0
# 1    0.315369  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1
# 2    0.307159  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1
# 3    0.487421  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1
# 4    0.215536  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1
# ..        ...                                   ...       ...
# 90   0.193457  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1
# 91   0.432432  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         0
# 92   0.352617  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1
# 93   0.472826  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         0
# 94   0.267574  8394d1cb-86b5-4b90-bc62-4b9b192a81f6         1
#
# [95 rows x 7 columns]

# %%
des = usersp.copy()
des['desistente'] = 2
for a in range(des.count().values[0]):
    if des['ateLista'].values[a]<4:
        des['desistente'][a]=1
    else:
        des['desistente'][a]=0
des[des['desistente']==1]
# Out:
#                                  user_id  ateLista  desistente
# 4   00ef5626-f029-49e8-aa27-1839357a55c0         1           1
# 30  da131b91-0126-41ca-9e6e-17dad2104ffd         3           1
# 82  ed3e0097-1441-41df-9e12-671039749c8e         2           1
# 84  0d327166-a647-4fa2-8def-1a64f55b223c         0           1

# %%
prob_total_des = pd.merge(des, prob_total, on=['user_id']).drop('aprovado', axis=1)
prob_total_des
# Out:
#                                  user_id  ateLista  desistente  total_subm  \
# 0   337cb03d-871a-4e38-8ab1-f79f8a0d8807        15           0        1437
# 1   ab916ff5-180e-401f-a1ff-de548e2d584d        15           0        1781
# 2   dc04e57b-43e7-448a-8f4c-1b29fc696a8e        15           0         353
# 3   716464a3-83d7-41f6-afcd-bd5a77644c7f        15           0         634
# 4   00ef5626-f029-49e8-aa27-1839357a55c0         1           1          63
# ..                                   ...       ...         ...         ...
# 90  1afdd554-892d-4746-81ab-76809311b711        15           0        1129
# 91  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f        15           0         363
# 92  bbf405b0-63d5-4031-9e5c-f4914a92c1dc        15           0         194
# 93  81c20d34-5d22-472d-8aac-7a215ce8296a        15           0         226
# 94  b9240348-c223-4c0d-b75f-09c522952143        15           0         146
#
#     totalError  totalAcert  acert_100                              class_id
# 0     0.703549    0.296451   0.128740  8394d1cb-86b5-4b90-bc62-4b9b192a81f6
# 1     0.617631    0.382369   0.086468  8394d1cb-86b5-4b90-bc62-4b9b192a81f6
# 2     0.490085    0.509915   0.311615  8394d1cb-86b5-4b90-bc62-4b9b192a81f6
# 3     0.542587    0.457413   0.309148  8394d1cb-86b5-4b90-bc62-4b9b192a81f6
# 4     0.746032    0.253968   0.253968  8394d1cb-86b5-4b90-bc62-4b9b192a81f6
# ..         ...         ...        ...                                   ...
# 90    0.721878    0.278122   0.139947  8394d1cb-86b5-4b90-bc62-4b9b192a81f6
# 91    0.363636    0.636364   0.352617  8394d1cb-86b5-4b90-bc62-4b9b192a81f6
# 92    0.221649    0.778351   0.644330  8394d1cb-86b5-4b90-bc62-4b9b192a81f6
# 93    0.292035    0.707965   0.539823  8394d1cb-86b5-4b90-bc62-4b9b192a81f6
# 94    0.431507    0.568493   0.458904  8394d1cb-86b5-4b90-bc62-4b9b192a81f6
#
# [95 rows x 8 columns]

# %%
plt.scatter(prob_total_des['totalError'].tolist(), 
            prob_total_des['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
plt.scatter(prob_total_des['acert_100'].tolist(), 
            prob_total_des['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
df_cont_subm = df_without_duplicates.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='total_subm')
df_cont_subm = df_cont_subm.groupby(['user_id'])['total_subm'].sum()

a = df_without_duplicates.drop(['_id', 'hitPercentage', 'listQuestions_id'], axis=1).drop_duplicates()
qtd_qPa = a.groupby(['user_id'])['question_id'].count().reset_index(name='totalQuest')

media_des0 = pd.merge(df_cont_subm, qtd_qPa, on=['user_id'])
media_des0['subm/quest'] = media_des0['total_subm'] / media_des0['totalQuest']
media_des = pd.merge(media_des0, des, on=['user_id'])
media_des
# Out:
#                                  user_id  total_subm  totalQuest  subm/quest  \
# 0   00ef5626-f029-49e8-aa27-1839357a55c0          63          15    4.200000
# 1   0343690d-9edd-48cf-be09-6dc1f4b3f61c         501         120    4.175000
# 2   035bbeb6-140b-413c-826d-9f92e36a31ae         433         124    3.491935
# 3   04a9f776-feee-4b63-8127-50270693e39f         318         124    2.564516
# 4   05c35721-051a-43fa-96b7-aeec0d0eafb5         914         119    7.680672
# ..                                   ...         ...         ...         ...
# 85  e8af96e7-0bac-45ff-a498-f22acb1af407         703         124    5.669355
# 86  ed3e0097-1441-41df-9e12-671039749c8e          37          16    2.312500
# 87  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f         363         124    2.927419
# 88  f5874924-7ed6-421c-ac14-3c0bccf51c24         184          86    2.139535
# 89  fe56d94c-26d1-4e75-85d1-0b10a07ece8b         441         117    3.769231
#
#     ateLista  desistente
# 0          1           1
# 1         15           0
# 2         15           0
# 3         15           0
# 4         15           0
# ..       ...         ...
# 85        15           0
# 86         2           1
# 87        15           0
# 88        15           0
# 89        15           0
#
# [90 rows x 6 columns]

# %%
plt.scatter(media_des['subm/quest'].tolist(), 
            media_des['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
prob_total_des
ind = prob_total_des.copy()
ind = ind.drop(['ateLista', 'class_id', 'total_subm'], axis=1)
ind = pd.merge(ind, media_des0, on=['user_id'])
ind['teste'] = ind['subm/quest'] * ind['totalAcert']
ind
# Out:
#                                  user_id  desistente  totalError  totalAcert  \
# 0   337cb03d-871a-4e38-8ab1-f79f8a0d8807           0    0.703549    0.296451
# 1   ab916ff5-180e-401f-a1ff-de548e2d584d           0    0.617631    0.382369
# 2   dc04e57b-43e7-448a-8f4c-1b29fc696a8e           0    0.490085    0.509915
# 3   716464a3-83d7-41f6-afcd-bd5a77644c7f           0    0.542587    0.457413
# 4   00ef5626-f029-49e8-aa27-1839357a55c0           1    0.746032    0.253968
# ..                                   ...         ...         ...         ...
# 90  1afdd554-892d-4746-81ab-76809311b711           0    0.721878    0.278122
# 91  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f           0    0.363636    0.636364
# 92  bbf405b0-63d5-4031-9e5c-f4914a92c1dc           0    0.221649    0.778351
# 93  81c20d34-5d22-472d-8aac-7a215ce8296a           0    0.292035    0.707965
# 94  b9240348-c223-4c0d-b75f-09c522952143           0    0.431507    0.568493
#
#     acert_100  total_subm  totalQuest  subm/quest     teste
# 0    0.128740        1437         124   11.588710  3.435484
# 1    0.086468        1781         124   14.362903  5.491935
# 2    0.311615         353         109    3.238532  1.651376
# 3    0.309148         634         124    5.112903  2.338710
# 4    0.253968          63          15    4.200000  1.066667
# ..        ...         ...         ...         ...       ...
# 90   0.139947        1129         124    9.104839  2.532258
# 91   0.352617         363         124    2.927419  1.862903
# 92   0.644330         194         124    1.564516  1.217742
# 93   0.539823         226         123    1.837398  1.300813
# 94   0.458904         146          65    2.246154  1.276923
#
# [95 rows x 9 columns]

# %%
plt.scatter(ind['teste'].tolist(), 
            ind['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
test_des = ind[ind['desistente']==1]
test_ndes = ind[ind['desistente']==0]

newind = ind[ind['teste']<=test_des['teste'].max()]
newind
# Out:
#                                  user_id  desistente  totalError  totalAcert  \
# 4   00ef5626-f029-49e8-aa27-1839357a55c0           1    0.746032    0.253968
# 28  c206e495-e2a7-4fad-8cc1-eed9690dc6dc           0    0.869565    0.130435
# 34  da131b91-0126-41ca-9e6e-17dad2104ffd           1    0.849593    0.150407
# 35  4f381a38-98c4-404b-b386-4cdda6a06565           0    0.196629    0.803371
# 63  1eb39a33-8898-4a33-a978-b1db76e94c88           0    0.403846    0.596154
# 80  82109970-6be9-42da-ad03-a96f1fcb194a           0    0.411017    0.588983
# 84  174b3116-31b8-4f19-bf06-2b597f96cc8a           0    0.344660    0.655340
# 86  ed3e0097-1441-41df-9e12-671039749c8e           1    0.567568    0.432432
# 88  0d327166-a647-4fa2-8def-1a64f55b223c           1    0.555556    0.444444
# 89  0d327166-a647-4fa2-8def-1a64f55b223c           1    0.555556    0.444444
#
#     acert_100  total_subm  totalQuest  subm/quest     teste
# 4    0.253968          63          15    4.200000  1.066667
# 28   0.130435          23           4    5.750000  0.750000
# 34   0.138211         246          32    7.687500  1.156250
# 35   0.707865         178         124    1.435484  1.153226
# 63   0.519231          52          29    1.793103  1.068966
# 80   0.555085         236         124    1.903226  1.120968
# 84   0.611650         206         124    1.661290  1.088710
# 86   0.432432          37          16    2.312500  1.000000
# 88   0.444444           9           4    2.250000  1.000000
# 89   0.444444           9           4    2.250000  1.000000

# %%
newind['teste2'] = ind['teste'] * ind['acert_100']
newind
# Out:
#                                  user_id  desistente  totalError  totalAcert  \
# 4   00ef5626-f029-49e8-aa27-1839357a55c0           1    0.746032    0.253968
# 28  c206e495-e2a7-4fad-8cc1-eed9690dc6dc           0    0.869565    0.130435
# 34  da131b91-0126-41ca-9e6e-17dad2104ffd           1    0.849593    0.150407
# 35  4f381a38-98c4-404b-b386-4cdda6a06565           0    0.196629    0.803371
# 63  1eb39a33-8898-4a33-a978-b1db76e94c88           0    0.403846    0.596154
# 80  82109970-6be9-42da-ad03-a96f1fcb194a           0    0.411017    0.588983
# 84  174b3116-31b8-4f19-bf06-2b597f96cc8a           0    0.344660    0.655340
# 86  ed3e0097-1441-41df-9e12-671039749c8e           1    0.567568    0.432432
# 88  0d327166-a647-4fa2-8def-1a64f55b223c           1    0.555556    0.444444
# 89  0d327166-a647-4fa2-8def-1a64f55b223c           1    0.555556    0.444444
#
#     acert_100  total_subm  totalQuest  subm/quest     teste    teste2
# 4    0.253968          63          15    4.200000  1.066667  0.270899
# 28   0.130435          23           4    5.750000  0.750000  0.097826
# 34   0.138211         246          32    7.687500  1.156250  0.159807
# 35   0.707865         178         124    1.435484  1.153226  0.816328
# 63   0.519231          52          29    1.793103  1.068966  0.555040
# 80   0.555085         236         124    1.903226  1.120968  0.622232
# 84   0.611650         206         124    1.661290  1.088710  0.665910
# 86   0.432432          37          16    2.312500  1.000000  0.432432
# 88   0.444444           9           4    2.250000  1.000000  0.444444
# 89   0.444444           9           4    2.250000  1.000000  0.444444

# %%
plt.scatter(newind['teste2'].tolist(), 
            newind['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
usersQtdAte[usersQtdAte['user_id']=='c206e495-e2a7-4fad-8cc1-eed9690dc6dc']
# Out:
#                                  user_id  \
# 73  c206e495-e2a7-4fad-8cc1-eed9690dc6dc
#
#                                 class_id  medialist  aprovado  qtdLista  \
# 73  8394d1cb-86b5-4b90-bc62-4b9b192a81f6        2.4         0         1
#
#     ateLista
# 73        15

# %%
name_class = '8394d1cb-86b5-4b90-bc62-4b9b192a81f6'
one_class = df_class_lop[df_class_lop['class_id']==name_class]

one_class['timeInSecounds'] = one_class['timeConsuming'].divide(1000).astype(int)

df_without_duplicates = one_class[one_class["timeInSecounds"] > 0].drop(['language','class_id','test_id','environment','timeConsuming','createdAt','timeInSecounds','char_change_number', 'ip', 'type', 'answer', 'lesson_id', 'id'], axis=1)
list1 = df_without_duplicates[df_without_duplicates['listQuestions_id']==order_lists[0]]
list1
# Out:
#                             _id  hitPercentage  \
# 44172  62ba0afe6b39e22d8ad545c5            0.0
# 44179  62ba0afe6b39e22d8ad545cc            0.0
# 44185  62ba0afe6b39e22d8ad545d2           25.0
# 44187  62ba0afe6b39e22d8ad545d4            0.0
# 44189  62ba0afe6b39e22d8ad545d6          100.0
# ...                         ...            ...
# 86723  62ba0b196b39e22d8ad5ebfc          100.0
# 86729  62ba0b196b39e22d8ad5ec02            0.0
# 86730  62ba0b196b39e22d8ad5ec03          100.0
# 86756  62ba0b196b39e22d8ad5ec1d            0.0
# 86763  62ba0b196b39e22d8ad5ec24            0.0
#
#                                     user_id  \
# 44172  12dcea94-7fab-4488-a626-b64cdb0d6465
# 44179  738c1374-344d-4d5c-a6e7-3b555e5b6f3b
# 44185  e785df2f-1b73-452f-bc30-eea29af9032f
# 44187  72290901-a9f2-490b-8c0d-32f90be1b1f7
# 44189  807c90d6-2fff-4624-8a3d-ca95bee2cb3f
# ...                                     ...
# 86723  5c23d612-3b35-4755-b143-aba053c5ca84
# 86729  1b845da2-b2e0-4e16-af64-c6b8673d14d3
# 86730  70b095d8-51e2-4c79-9a9c-4cb193c1eef1
# 86756  5f36ea3e-de67-4eac-87ec-7df52b78f3d5
# 86763  72290901-a9f2-490b-8c0d-32f90be1b1f7
#
#                                 question_id  \
# 44172  7d0c47d7-c789-422d-95cd-d4257ef8d292
# 44179  166c3c46-44b0-437b-8121-37a1fe6ba586
# 44185  eb962e97-1922-49d9-be27-932e4218a7b7
# 44187  166c3c46-44b0-437b-8121-37a1fe6ba586
# 44189  7d0c47d7-c789-422d-95cd-d4257ef8d292
# ...                                     ...
# 86723  166c3c46-44b0-437b-8121-37a1fe6ba586
# 86729  7d0c47d7-c789-422d-95cd-d4257ef8d292
# 86730  1a56bcee-0cb1-46f2-90fe-fde9b5c7bef8
# 86756  7d0c47d7-c789-422d-95cd-d4257ef8d292
# 86763  7d0c47d7-c789-422d-95cd-d4257ef8d292
#
#                            listQuestions_id
# 44172  4f3452ae-87d4-4a5f-9532-c7634da2cff0
# 44179  4f3452ae-87d4-4a5f-9532-c7634da2cff0
# 44185  4f3452ae-87d4-4a5f-9532-c7634da2cff0
# 44187  4f3452ae-87d4-4a5f-9532-c7634da2cff0
# 44189  4f3452ae-87d4-4a5f-9532-c7634da2cff0
# ...                                     ...
# 86723  4f3452ae-87d4-4a5f-9532-c7634da2cff0
# 86729  4f3452ae-87d4-4a5f-9532-c7634da2cff0
# 86730  4f3452ae-87d4-4a5f-9532-c7634da2cff0
# 86756  4f3452ae-87d4-4a5f-9532-c7634da2cff0
# 86763  4f3452ae-87d4-4a5f-9532-c7634da2cff0
#
# [2317 rows x 5 columns]

# %%
des_aqui = des.copy()

for a in range(des_aqui.count().values[0]):
    if des_aqui['ateLista'].values[a]<1:
        des_aqui['desistente'][a]=1
    else:
        des_aqui['desistente'][a]=0

df_erro = list1[list1["hitPercentage"] == 0]
df_erro = df_erro.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='totalError')
df_erro = df_erro.groupby(['user_id'])['totalError'].sum()

#buscando quantidade de questoes certas por lista por aluno
df_acerto = list1[list1["hitPercentage"] > 0]
df_acerto = df_acerto.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='totalAcert')
df_acerto = df_acerto.groupby(['user_id'])['totalAcert'].sum()

#buscando quantidade de questoes que com 100% de acerto por lista por aluno
df_100 = list1[list1["hitPercentage"] == 100].drop_duplicates()
df_100 = df_100.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='acert_100')
df_100 = df_100.groupby(['user_id'])['acert_100'].sum()

df_cont_subm = list1.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='total_subm')
df_cont_subm = df_cont_subm.groupby(['user_id'])['total_subm'].sum()

a = list1.drop(['_id', 'hitPercentage', 'listQuestions_id'], axis=1).drop_duplicates()
qtd_qPa = a.groupby(['user_id'])['question_id'].count().reset_index(name='totalQuest')

media_list1 = pd.merge(df_cont_subm, qtd_qPa, on=['user_id'])
media_list1['subm/quest'] = media_list1['total_subm'] / media_list1['totalQuest']

#buscar se o aluno chegou a tirar 100 na questão ou a nota final.
#há mais de um acerto, pois há mais vezes que tentam tirar mais que zero, mas nem sempre chegam no 100
#avaliar a possibilidade de colocar a nota maxima do aluno em coluna

df_list1 = pd.merge(df_erro, df_acerto, on=['user_id'], how='outer')
df_list1 = pd.merge(df_list1, df_100, on=['user_id'], how='outer')
df_list1.replace(np.NaN, 0, inplace = True)
df_list1 = pd.merge(df_list1, des_aqui, on=['user_id'])
df_list1 = pd.merge(df_list1, media_list1, on=['user_id'])
des_aqui[des_aqui['desistente']==1]
# Out:
#                                  user_id  ateLista  desistente
# 84  0d327166-a647-4fa2-8def-1a64f55b223c         0           1

# %%
plt.scatter(df_list1['totalError'].tolist(), 
            df_list1['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
plt.scatter(df_list1['acert_100'].tolist(), 
            df_list1['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
plt.scatter(df_list1['subm/quest'].tolist(), 
            df_list1['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
#df_list1['teste'] = df_list1['totalError'] * df_list1['subm/quest']
#grap = df_list1[df_list1['teste']>0]
#plt.scatter(grap['teste'].tolist(), 
#            grap['desistente'].tolist(), 
#            marker='o')
#plt.show()
#grap['teste'].min()
#grap[grap['desistente']==1]

# %%
df_list1['totalError'] = df_list1['totalError'] / df_list1['total_subm']
df_list1['totalAcert'] = df_list1['totalAcert'] / df_list1['total_subm']
df_list1['acert_100'] = df_list1['acert_100'] / df_list1['total_subm']
df_list1
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 0   00ef5626-f029-49e8-aa27-1839357a55c0    0.814815    0.185185   0.185185
# 1   0343690d-9edd-48cf-be09-6dc1f4b3f61c    0.500000    0.500000   0.500000
# 2   035bbeb6-140b-413c-826d-9f92e36a31ae    0.444444    0.555556   0.555556
# 3   04a9f776-feee-4b63-8127-50270693e39f    0.240000    0.760000   0.360000
# 4   05c35721-051a-43fa-96b7-aeec0d0eafb5    0.735294    0.264706   0.264706
# ..                                   ...         ...         ...        ...
# 84  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f    0.500000    0.500000   0.500000
# 85  f5874924-7ed6-421c-ac14-3c0bccf51c24    0.722222    0.277778   0.277778
# 86  fe56d94c-26d1-4e75-85d1-0b10a07ece8b    0.666667    0.333333   0.333333
# 87  2d994fe7-d982-4870-b187-606862334830    0.000000    1.000000   0.952381
# 88  bbf405b0-63d5-4031-9e5c-f4914a92c1dc    0.000000    1.000000   1.000000
#
#     ateLista  desistente  total_subm  totalQuest  subm/quest
# 0          1           0          27           5         5.4
# 1         15           0          14           5         2.8
# 2         15           0           9           5         1.8
# 3         15           0          25           5         5.0
# 4         15           0          34           5         6.8
# ..       ...         ...         ...         ...         ...
# 84        15           0          12           5         2.4
# 85        15           0          18           5         3.6
# 86        15           0          15           5         3.0
# 87        15           0          21           2        10.5
# 88        15           0           6           5         1.2
#
# [89 rows x 9 columns]

# %%
plt.scatter(df_list1['totalError'].tolist(), 
            df_list1['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
plt.scatter(df_list1['acert_100'].tolist(), 
            df_list1['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
plt.scatter(df_list1['subm/quest'].tolist(), 
            df_list1['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
df_list1['teste'] = df_list1['totalError'] * df_list1['subm/quest']
grap1 = df_list1[df_list1['teste']>0]
plt.scatter(grap1['teste'].tolist(), 
            grap1['desistente'].tolist(), 
            marker='o')
plt.show()
print(grap1['teste'].min())
print(grap1['teste'].max())
# Out:
# 0.19999999999999998
# 17.6

# %%
grap = grap1[grap1['desistente']==1]
#test_ndes = ind[ind['desistente']==0]

teste1 = grap1[grap1['teste']<=grap['teste'].max()]
teste1[teste1['totalError']==teste1['totalError'].max()]
# Out:
#                                 user_id  totalError  totalAcert  acert_100  \
# 7  0d327166-a647-4fa2-8def-1a64f55b223c    0.555556    0.444444   0.444444
#
#    ateLista  desistente  total_subm  totalQuest  subm/quest  teste
# 7         0           1           9           4        2.25   1.25

# %%
#o que desistiu foi o que mais errou dentre todos esses
#

# %%
df_list1['teste'] = df_list1['totalAcert'] * df_list1['subm/quest']
grap1 = df_list1[df_list1['teste']>0]
plt.scatter(grap1['teste'].tolist(), 
            grap1['desistente'].tolist(), 
            marker='o')
plt.show()
print(grap1['teste'].min())
print(grap1['teste'].max())
# Out:
# 0.75
# 10.5

# %%
grap = grap1[grap1['desistente']==1]
#test_ndes = ind[ind['desistente']==0]

teste1 = grap1[grap1['teste']<=grap['teste'].max()]
teste1[teste1['totalError']>0.5]
#dos 3 que menos subm/quest, desistiu quem mais errou
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 0   00ef5626-f029-49e8-aa27-1839357a55c0    0.814815    0.185185   0.185185
# 7   0d327166-a647-4fa2-8def-1a64f55b223c    0.555556    0.444444   0.444444
# 11  16e204c4-d406-46b2-9905-a159c9e02562    0.821429    0.178571   0.178571
# 19  230c55ef-88d5-4149-aad5-0696c4aa5df8    0.545455    0.454545   0.454545
# 24  35a86d2d-e321-4d35-997e-e908d5335bbe    0.545455    0.454545   0.454545
# 29  43dd8e83-481a-4abb-9773-f759d482affd    0.807692    0.192308   0.192308
# 38  61378206-cf75-4fc0-95dc-43f6e81a788c    0.642857    0.357143   0.357143
# 43  71f3d713-6085-40f2-8c79-b18419aa06d7    0.687500    0.312500   0.312500
# 45  738c1374-344d-4d5c-a6e7-3b555e5b6f3b    0.933333    0.066667   0.066667
# 48  7e29de1e-0745-408e-b528-1a6433489ed9    0.615385    0.384615   0.384615
# 51  81c20d34-5d22-472d-8aac-7a215ce8296a    0.791667    0.208333   0.208333
# 54  872865e3-6303-4b28-bd84-489d7e9111f6    0.843750    0.156250   0.156250
# 55  8b8abf76-bef9-4d7f-a0e8-afead692300e    0.807692    0.192308   0.192308
# 60  9ab39257-de7e-4ddd-951e-371a89329d6c    0.838710    0.161290   0.161290
# 66  aea89293-579b-4e7a-b756-af41468477b8    0.705882    0.294118   0.294118
# 67  b9240348-c223-4c0d-b75f-09c522952143    0.736842    0.263158   0.263158
# 68  bafe35cc-ce7e-484a-b496-6dcf0f99167e    0.722222    0.277778   0.277778
# 70  c206e495-e2a7-4fad-8cc1-eed9690dc6dc    0.869565    0.130435   0.130435
# 71  c44de1e4-1812-4155-a330-2f17d8bc9d23    0.750000    0.250000   0.250000
# 83  ed3e0097-1441-41df-9e12-671039749c8e    0.736842    0.263158   0.263158
# 85  f5874924-7ed6-421c-ac14-3c0bccf51c24    0.722222    0.277778   0.277778
# 86  fe56d94c-26d1-4e75-85d1-0b10a07ece8b    0.666667    0.333333   0.333333
#
#     ateLista  desistente  total_subm  totalQuest  subm/quest  teste
# 0          1           0          27           5    5.400000    1.0
# 7          0           1           9           4    2.250000    1.0
# 11        15           0          28           5    5.600000    1.0
# 19        15           0          11           5    2.200000    1.0
# 24        15           0          11           5    2.200000    1.0
# 29        15           0          26           5    5.200000    1.0
# 38        15           0          14           5    2.800000    1.0
# 43        15           0          16           5    3.200000    1.0
# 45        15           0          75           5   15.000000    1.0
# 48        15           0          13           5    2.600000    1.0
# 51        15           0          24           5    4.800000    1.0
# 54        15           0          32           5    6.400000    1.0
# 55        15           0          26           5    5.200000    1.0
# 60        15           0          31           5    6.200000    1.0
# 66        15           0          17           5    3.400000    1.0
# 67        15           0          19           5    3.800000    1.0
# 68        15           0          18           5    3.600000    1.0
# 70        15           0          23           3    7.666667    1.0
# 71        15           0          20           5    4.000000    1.0
# 83         2           0          19           5    3.800000    1.0
# 85        15           0          18           5    3.600000    1.0
# 86        15           0          15           5    3.000000    1.0

# %%
name_class = '8394d1cb-86b5-4b90-bc62-4b9b192a81f6'
one_class = df_class_lop[df_class_lop['class_id']==name_class]

one_class['timeInSecounds'] = one_class['timeConsuming'].divide(1000).astype(int)

df_without_duplicates = one_class[one_class["timeInSecounds"] > 0].drop(['language','class_id','test_id','environment','timeConsuming','createdAt','timeInSecounds','char_change_number', 'ip', 'type', 'answer', 'lesson_id', 'id'], axis=1)
list2 = list1.copy()
list2 = list2.append(df_without_duplicates[df_without_duplicates['listQuestions_id']==order_lists[1]])
list2 = list2.reset_index()

a = des[ des['ateLista'] < 1]
indexNames = []
for i in a.values:
    indexNames.append(list2[list2['user_id'] == i[0]].index)
    
list2 = list2.drop(list2.index[indexNames])

for a in range(des_aqui.count().values[0]):
    if des_aqui['ateLista'].values[a]<2:
        des_aqui['desistente'][a]=1
    else:
        des_aqui['desistente'][a]=0

a = des[ des['ateLista'] < 1]
indexNames = []
for i in a.values:
    indexNames.append(des_aqui[des_aqui['user_id'] == i[0]].index)
des_aqui = des_aqui.drop(des_aqui.index[indexNames])

df_erro = list2[list2["hitPercentage"] == 0]
df_erro = df_erro.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='totalError')
df_erro = df_erro.groupby(['user_id'])['totalError'].sum()

#buscando quantidade de questoes certas por lista por aluno
df_acerto = list2[list2["hitPercentage"] > 0]
df_acerto = df_acerto.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='totalAcert')
df_acerto = df_acerto.groupby(['user_id'])['totalAcert'].sum()

#buscando quantidade de questoes que com 100% de acerto por lista por aluno
df_100 = list2[list2["hitPercentage"] == 100].drop_duplicates()
df_100 = df_100.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='acert_100')
df_100 = df_100.groupby(['user_id'])['acert_100'].sum()

df_cont_subm0 = list2.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='total_subm')
df_cont_subm = df_cont_subm0.groupby(['user_id'])['total_subm'].sum()

#a = list2.drop(['_id', 'hitPercentage', 'listQuestions_id'], axis=1).drop_duplicates()
qtd_qPa = df_cont_subm0.groupby(['user_id'])['question_id'].count().reset_index(name='totalQuest')

media_list2 = pd.merge(df_cont_subm, qtd_qPa, on=['user_id'])
media_list2['subm/quest'] = media_list2['total_subm'] / media_list2['totalQuest']

#buscar se o aluno chegou a tirar 100 na questão ou a nota final.
#há mais de um acerto, pois há mais vezes que tentam tirar mais que zero, mas nem sempre chegam no 100
#avaliar a possibilidade de colocar a nota maxima do aluno em coluna

df_list2 = pd.merge(df_erro, df_acerto, on=['user_id'], how='outer')
df_list2 = pd.merge(df_list2, df_100, on=['user_id'], how='outer')
df_list2.replace(np.NaN, 0, inplace = True)
df_list2 = pd.merge(df_list2, des_aqui, on=['user_id'])
df_list2 = pd.merge(df_list2, media_list2, on=['user_id'])
df_list2
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 0   00ef5626-f029-49e8-aa27-1839357a55c0          47          16         16
# 1   0343690d-9edd-48cf-be09-6dc1f4b3f61c          15          29         29
# 2   035bbeb6-140b-413c-826d-9f92e36a31ae          13          15         15
# 3   04a9f776-feee-4b63-8127-50270693e39f          13          30         20
# 4   05c35721-051a-43fa-96b7-aeec0d0eafb5          63          42         36
# ..                                   ...         ...         ...        ...
# 84  e8af96e7-0bac-45ff-a498-f22acb1af407          63          19         19
# 85  ed3e0097-1441-41df-9e12-671039749c8e          17          15         15
# 86  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f          42          23         17
# 87  f5874924-7ed6-421c-ac14-3c0bccf51c24          19          15         15
# 88  fe56d94c-26d1-4e75-85d1-0b10a07ece8b          19          15         15
#
#     ateLista  desistente  total_subm  totalQuest  subm/quest
# 0          1           1          63          15    4.200000
# 1         15           0          44          15    2.933333
# 2         15           0          28          15    1.866667
# 3         15           0          43          15    2.866667
# 4         15           0         105          15    7.000000
# ..       ...         ...         ...         ...         ...
# 84        15           0          82          15    5.466667
# 85         2           0          32          15    2.133333
# 86        15           0          65          15    4.333333
# 87        15           0          34          15    2.266667
# 88        15           0          34          15    2.266667
#
# [89 rows x 9 columns]

# %%
plt.scatter(df_list2['totalError'].tolist(), 
            df_list2['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
plt.scatter(df_list2['acert_100'].tolist(), 
            df_list2['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
plt.scatter(df_list2['subm/quest'].tolist(), 
            df_list2['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
df_list2['totalError'] = df_list2['totalError'] / df_list2['total_subm']
df_list2['totalAcert'] = df_list2['totalAcert'] / df_list2['total_subm']
df_list2['acert_100'] = df_list2['acert_100'] / df_list2['total_subm']
df_list2
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 0   00ef5626-f029-49e8-aa27-1839357a55c0    0.746032    0.253968   0.253968
# 1   0343690d-9edd-48cf-be09-6dc1f4b3f61c    0.340909    0.659091   0.659091
# 2   035bbeb6-140b-413c-826d-9f92e36a31ae    0.464286    0.535714   0.535714
# 3   04a9f776-feee-4b63-8127-50270693e39f    0.302326    0.697674   0.465116
# 4   05c35721-051a-43fa-96b7-aeec0d0eafb5    0.600000    0.400000   0.342857
# ..                                   ...         ...         ...        ...
# 84  e8af96e7-0bac-45ff-a498-f22acb1af407    0.768293    0.231707   0.231707
# 85  ed3e0097-1441-41df-9e12-671039749c8e    0.531250    0.468750   0.468750
# 86  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f    0.646154    0.353846   0.261538
# 87  f5874924-7ed6-421c-ac14-3c0bccf51c24    0.558824    0.441176   0.441176
# 88  fe56d94c-26d1-4e75-85d1-0b10a07ece8b    0.558824    0.441176   0.441176
#
#     ateLista  desistente  total_subm  totalQuest  subm/quest
# 0          1           1          63          15    4.200000
# 1         15           0          44          15    2.933333
# 2         15           0          28          15    1.866667
# 3         15           0          43          15    2.866667
# 4         15           0         105          15    7.000000
# ..       ...         ...         ...         ...         ...
# 84        15           0          82          15    5.466667
# 85         2           0          32          15    2.133333
# 86        15           0          65          15    4.333333
# 87        15           0          34          15    2.266667
# 88        15           0          34          15    2.266667
#
# [89 rows x 9 columns]

# %%
plt.scatter(df_list2['totalError'].tolist(), 
            df_list2['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
plt.scatter(df_list2['acert_100'].tolist(), 
            df_list2['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
df_list2['teste'] = df_list2['totalError'] * df_list2['subm/quest']
grap2 = df_list2[df_list2['teste']>0]
plt.scatter(grap2['teste'].tolist(), 
            grap2['desistente'].tolist(), 
            marker='o')
plt.show()
print(grap2['teste'].min())
print(grap2['teste'].max())
# Out:
# 0.06666666666666667
# 13.6

# %%
grap = grap2[grap2['desistente']==1]
#test_ndes = ind[ind['desistente']==0]

teste1 = grap2[grap2['teste']<=grap['teste'].max()]
teste1[teste1['totalError']>0.74]
#o desistente submeteu mais questoes, por mais que tenha um indice de erro menor
#de toda forma, primeiro erro dentre quem mais errou, no fim. oberservar o que houve com este aluno que errou mais
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 0   00ef5626-f029-49e8-aa27-1839357a55c0    0.746032    0.253968   0.253968
# 61  9ab39257-de7e-4ddd-951e-371a89329d6c    0.754098    0.245902   0.245902
#
#     ateLista  desistente  total_subm  totalQuest  subm/quest     teste
# 0          1           1          63          15    4.200000  3.133333
# 61        15           0          61          15    4.066667  3.066667

# %%
df_list2['teste'] = df_list2['totalAcert'] * df_list2['subm/quest']
grap2 = df_list2[df_list2['teste']>0]
plt.scatter(grap2['teste'].tolist(), 
            grap2['desistente'].tolist(), 
            marker='o')
plt.show()
print(grap2['teste'].min())
print(grap2['teste'].max())
# Out:
# 0.9285714285714286
# 3.7

# %%
grap = grap2[grap2['desistente']==1]
#test_ndes = ind[ind['desistente']==0]

teste1 = grap2[grap2['teste']<=grap['teste'].max()]
teste1[teste1['totalError']>0.7]
#dos 4 que menos subm/quest, o segundo que mais errou
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 0   00ef5626-f029-49e8-aa27-1839357a55c0    0.746032    0.253968   0.253968
# 10  16e204c4-d406-46b2-9905-a159c9e02562    0.822222    0.177778   0.177778
# 14  1afdd554-892d-4746-81ab-76809311b711    0.737705    0.262295   0.262295
# 34  55c3cbad-e6e2-4c79-88e9-b03c0416c515    0.789474    0.210526   0.197368
# 38  6055380e-fafa-4dcb-b6db-34fcd0843098    0.737705    0.262295   0.262295
# 46  738c1374-344d-4d5c-a6e7-3b555e5b6f3b    0.852941    0.147059   0.147059
# 61  9ab39257-de7e-4ddd-951e-371a89329d6c    0.754098    0.245902   0.245902
# 72  c206e495-e2a7-4fad-8cc1-eed9690dc6dc    0.869565    0.130435   0.130435
# 80  da131b91-0126-41ca-9e6e-17dad2104ffd    0.802469    0.197531   0.197531
#
#     ateLista  desistente  total_subm  totalQuest  subm/quest     teste
# 0          1           1          63          15    4.200000  1.066667
# 10        15           0          90          15    6.000000  1.066667
# 14        15           0          61          15    4.066667  1.066667
# 34        15           0          76          15    5.066667  1.066667
# 38        15           0          61          15    4.066667  1.066667
# 46        15           0         102          15    6.800000  1.000000
# 61        15           0          61          15    4.066667  1.000000
# 72        15           0          23           3    7.666667  1.000000
# 80         3           0          81          15    5.400000  1.066667

# %%
name_class = '8394d1cb-86b5-4b90-bc62-4b9b192a81f6'
one_class = df_class_lop[df_class_lop['class_id']==name_class]

one_class['timeInSecounds'] = one_class['timeConsuming'].divide(1000).astype(int)

df_without_duplicates = one_class[one_class["timeInSecounds"] > 0].drop(['language','class_id','test_id','environment','timeConsuming','createdAt','timeInSecounds','char_change_number', 'ip', 'type', 'answer', 'lesson_id', 'id'], axis=1)
list3 = list2.copy()
list3 = list3.append(df_without_duplicates[df_without_duplicates['listQuestions_id']==order_lists[2]])
list3 = list3.reset_index()

a = des[ des['ateLista'] == 1]
indexNames = []
for i in a.values:
    indexNames.append(list3[list3['user_id'] == i[0]].index)
    
list3 = list3.drop(list3.index[indexNames])

for a in range(des_aqui.count().values[0]):
    if des_aqui['ateLista'].values[a]<3:
        des_aqui['desistente'][a]=1
    else:
        des_aqui['desistente'][a]=0

a = des[ des['ateLista'] < 1]
indexNames = []
for i in a.values:
    indexNames.append(des_aqui[des_aqui['user_id'] == i[0]].index)
des_aqui = des_aqui.drop(des_aqui.index[indexNames])

df_erro = list3[list3["hitPercentage"] == 0]
df_erro = df_erro.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='totalError')
df_erro = df_erro.groupby(['user_id'])['totalError'].sum()

#buscando quantidade de questoes certas por lista por aluno
df_acerto = list3[list3["hitPercentage"] > 0]
df_acerto = df_acerto.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='totalAcert')
df_acerto = df_acerto.groupby(['user_id'])['totalAcert'].sum()

#buscando quantidade de questoes que com 100% de acerto por lista por aluno
df_100 = list3[list3["hitPercentage"] == 100].drop_duplicates()
df_100 = df_100.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='acert_100')
df_100 = df_100.groupby(['user_id'])['acert_100'].sum()

df_cont_subm0 = list3.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='total_subm')
df_cont_subm = df_cont_subm0.groupby(['user_id'])['total_subm'].sum()

#a = list2.drop(['_id', 'hitPercentage', 'listQuestions_id'], axis=1).drop_duplicates()
qtd_qPa = df_cont_subm0.groupby(['user_id'])['question_id'].count().reset_index(name='totalQuest')

media_list3 = pd.merge(df_cont_subm, qtd_qPa, on=['user_id'])
media_list3['subm/quest'] = media_list3['total_subm'] / media_list3['totalQuest']

#buscar se o aluno chegou a tirar 100 na questão ou a nota final.
#há mais de um acerto, pois há mais vezes que tentam tirar mais que zero, mas nem sempre chegam no 100
#avaliar a possibilidade de colocar a nota maxima do aluno em coluna

df_list3 = pd.merge(df_erro, df_acerto, on=['user_id'], how='outer')
df_list3 = pd.merge(df_list3, df_100, on=['user_id'], how='outer')
df_list3.replace(np.NaN, 0, inplace = True)
df_list3 = pd.merge(df_list3, des_aqui, on=['user_id'])
df_list3 = pd.merge(df_list3, media_list3, on=['user_id'])
df_list3
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 0   0343690d-9edd-48cf-be09-6dc1f4b3f61c          44          47         46
# 1   035bbeb6-140b-413c-826d-9f92e36a31ae          22          29         27
# 2   04a9f776-feee-4b63-8127-50270693e39f          24          46         35
# 3   05c35721-051a-43fa-96b7-aeec0d0eafb5          97          68         54
# 4   06bddeab-42f1-428a-88d1-adf096da3432         288          53         34
# ..                                   ...         ...         ...        ...
# 83  e8af96e7-0bac-45ff-a498-f22acb1af407         160          47         33
# 84  ed3e0097-1441-41df-9e12-671039749c8e          21          16         16
# 85  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f          43          35         29
# 86  f5874924-7ed6-421c-ac14-3c0bccf51c24          27          32         28
# 87  fe56d94c-26d1-4e75-85d1-0b10a07ece8b          50          27         27
#
#     ateLista  desistente  total_subm  totalQuest  subm/quest
# 0         15           0          91          27    3.370370
# 1         15           0          51          27    1.888889
# 2         15           0          70          27    2.592593
# 3         15           0         165          27    6.111111
# 4         15           0         341          27   12.629630
# ..       ...         ...         ...         ...         ...
# 83        15           0         207          27    7.666667
# 84         2           1          37          16    2.312500
# 85        15           0          78          27    2.888889
# 86        15           0          59          27    2.185185
# 87        15           0          77          27    2.851852
#
# [88 rows x 9 columns]

# %%
plt.scatter(df_list3['totalError'].tolist(), 
            df_list3['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
plt.scatter(df_list3['acert_100'].tolist(), 
            df_list3['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
plt.scatter(df_list3['subm/quest'].tolist(), 
            df_list3['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
df_list3['totalError'] = df_list3['totalError'] / df_list3['total_subm']
df_list3['totalAcert'] = df_list3['totalAcert'] / df_list3['total_subm']
df_list3['acert_100'] = df_list3['acert_100'] / df_list3['total_subm']
df_list3
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 0   0343690d-9edd-48cf-be09-6dc1f4b3f61c    0.483516    0.516484   0.505495
# 1   035bbeb6-140b-413c-826d-9f92e36a31ae    0.431373    0.568627   0.529412
# 2   04a9f776-feee-4b63-8127-50270693e39f    0.342857    0.657143   0.500000
# 3   05c35721-051a-43fa-96b7-aeec0d0eafb5    0.587879    0.412121   0.327273
# 4   06bddeab-42f1-428a-88d1-adf096da3432    0.844575    0.155425   0.099707
# ..                                   ...         ...         ...        ...
# 83  e8af96e7-0bac-45ff-a498-f22acb1af407    0.772947    0.227053   0.159420
# 84  ed3e0097-1441-41df-9e12-671039749c8e    0.567568    0.432432   0.432432
# 85  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f    0.551282    0.448718   0.371795
# 86  f5874924-7ed6-421c-ac14-3c0bccf51c24    0.457627    0.542373   0.474576
# 87  fe56d94c-26d1-4e75-85d1-0b10a07ece8b    0.649351    0.350649   0.350649
#
#     ateLista  desistente  total_subm  totalQuest  subm/quest
# 0         15           0          91          27    3.370370
# 1         15           0          51          27    1.888889
# 2         15           0          70          27    2.592593
# 3         15           0         165          27    6.111111
# 4         15           0         341          27   12.629630
# ..       ...         ...         ...         ...         ...
# 83        15           0         207          27    7.666667
# 84         2           1          37          16    2.312500
# 85        15           0          78          27    2.888889
# 86        15           0          59          27    2.185185
# 87        15           0          77          27    2.851852
#
# [88 rows x 9 columns]

# %%
plt.scatter(df_list3['totalError'].tolist(), 
            df_list3['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
plt.scatter(df_list3['acert_100'].tolist(), 
            df_list3['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
df_list3['teste'] = df_list3['totalError'] * df_list3['subm/quest']
grap3 = df_list3[df_list3['teste']>0]
plt.scatter(grap3['teste'].tolist(), 
            grap3['desistente'].tolist(), 
            marker='o')
plt.show()
print(grap3['teste'].min())
print(grap3['teste'].max())
# Out:
# 0.07407407407407407
# 12.925925925925926

# %%
grap = grap3[grap3['desistente']==1]
#test_ndes = ind[ind['desistente']==0]

teste1 = grap3[grap3['teste']<=grap['teste'].max()]
teste1[teste1['totalError']==teste1['totalError'].max()]
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 84  ed3e0097-1441-41df-9e12-671039749c8e    0.567568    0.432432   0.432432
#
#     ateLista  desistente  total_subm  totalQuest  subm/quest   teste
# 84         2           1          37          16      2.3125  1.3125

# %%
df_list3['teste'] = df_list3['totalAcert'] * df_list3['subm/quest']
grap3 = df_list3[df_list3['teste']>0]
plt.scatter(grap3['teste'].tolist(), 
            grap3['desistente'].tolist(), 
            marker='o')
plt.show()
print(grap3['teste'].min())
print(grap3['teste'].max())
# Out:
# 0.9615384615384616
# 3.7

# %%
grap = grap3[grap3['desistente']==1]
#test_ndes = ind[ind['desistente']==0]

teste1 = grap3[grap3['teste']<=grap['teste'].max()]
teste1[teste1['totalError']==teste1['totalError'].max()]
teste1
#6/88
#dos 3 que menos submeteram, quem mais errou
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 16  1eb39a33-8898-4a33-a978-b1db76e94c88    0.404762    0.595238   0.595238
# 39  64cc36c5-4fcc-445a-b360-3a25c9783645    0.730337    0.269663   0.269663
# 67  b9240348-c223-4c0d-b75f-09c522952143    0.564516    0.435484   0.435484
# 71  c206e495-e2a7-4fad-8cc1-eed9690dc6dc    0.869565    0.130435   0.130435
# 84  ed3e0097-1441-41df-9e12-671039749c8e    0.567568    0.432432   0.432432
# 87  fe56d94c-26d1-4e75-85d1-0b10a07ece8b    0.649351    0.350649   0.350649
#
#     ateLista  desistente  total_subm  totalQuest  subm/quest     teste
# 16        15           0          42          26    1.615385  0.961538
# 39        15           0          89          24    3.708333  1.000000
# 67        15           0          62          27    2.296296  1.000000
# 71        15           0          23           3    7.666667  1.000000
# 84         2           1          37          16    2.312500  1.000000
# 87        15           0          77          27    2.851852  1.000000

# %%
name_class = '8394d1cb-86b5-4b90-bc62-4b9b192a81f6'
one_class = df_class_lop[df_class_lop['class_id']==name_class]

one_class['timeInSecounds'] = one_class['timeConsuming'].divide(1000).astype(int)

df_without_duplicates = one_class[one_class["timeInSecounds"] > 0].drop(['language','class_id','test_id','environment','timeConsuming','createdAt','timeInSecounds','char_change_number', 'ip', 'type', 'answer', 'lesson_id', 'id'], axis=1)
list4 = list3.copy()
list4 = list4.append(df_without_duplicates[df_without_duplicates['listQuestions_id']==order_lists[3]])
#list4 = list4.reset_index()

a = des[ des['ateLista'] == 2]
indexNames = []
for i in a.values:
    indexNames.append(list4[list4['user_id'] == i[0]].index)
    
list4 = list4.drop(list4.index[indexNames])

for a in range(des_aqui.count().values[0]):
    if des_aqui['ateLista'].values[a]<4:
        des_aqui['desistente'][a]=1
    else:
        des_aqui['desistente'][a]=0

a = des[ des['ateLista'] ==2]
indexNames = []
for i in a.values:
    indexNames.append(des_aqui[des_aqui['user_id'] == i[0]].index)
des_aqui = des_aqui.drop(des_aqui.index[indexNames])

df_erro = list4[list4["hitPercentage"] == 0]
df_erro = df_erro.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='totalError')
df_erro = df_erro.groupby(['user_id'])['totalError'].sum()

#buscando quantidade de questoes certas por lista por aluno
df_acerto = list4[list4["hitPercentage"] > 0]
df_acerto = df_acerto.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='totalAcert')
df_acerto = df_acerto.groupby(['user_id'])['totalAcert'].sum()

#buscando quantidade de questoes que com 100% de acerto por lista por aluno
df_100 = list4[list4["hitPercentage"] == 100].drop_duplicates()
df_100 = df_100.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='acert_100')
df_100 = df_100.groupby(['user_id'])['acert_100'].sum()

df_cont_subm0 = list4.groupby(['user_id','listQuestions_id','question_id'])['hitPercentage'].count().reset_index(name='total_subm')
df_cont_subm = df_cont_subm0.groupby(['user_id'])['total_subm'].sum()

#a = list2.drop(['_id', 'hitPercentage', 'listQuestions_id'], axis=1).drop_duplicates()
qtd_qPa = df_cont_subm0.groupby(['user_id'])['question_id'].count().reset_index(name='totalQuest')

media_list4 = pd.merge(df_cont_subm, qtd_qPa, on=['user_id'])
media_list4['subm/quest'] = media_list4['total_subm'] / media_list4['totalQuest']

#buscar se o aluno chegou a tirar 100 na questão ou a nota final.
#há mais de um acerto, pois há mais vezes que tentam tirar mais que zero, mas nem sempre chegam no 100
#avaliar a possibilidade de colocar a nota maxima do aluno em coluna

df_list4 = pd.merge(df_erro, df_acerto, on=['user_id'], how='outer')
df_list4 = pd.merge(df_list4, df_100, on=['user_id'], how='outer')
df_list4.replace(np.NaN, 0, inplace = True)
df_list4 = pd.merge(df_list4, des_aqui, on=['user_id'])
df_list4 = pd.merge(df_list4, media_list4, on=['user_id'])
df_list4
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 0   0343690d-9edd-48cf-be09-6dc1f4b3f61c          48          57         53
# 1   035bbeb6-140b-413c-826d-9f92e36a31ae          28          41         34
# 2   04a9f776-feee-4b63-8127-50270693e39f          24          56         43
# 3   05c35721-051a-43fa-96b7-aeec0d0eafb5         105          89         61
# 4   06bddeab-42f1-428a-88d1-adf096da3432         318          80         42
# ..                                   ...         ...         ...        ...
# 82  e785df2f-1b73-452f-bc30-eea29af9032f         271         105         45
# 83  e8af96e7-0bac-45ff-a498-f22acb1af407         162          60         42
# 84  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f          51          44         37
# 85  f5874924-7ed6-421c-ac14-3c0bccf51c24          30          45         35
# 86  fe56d94c-26d1-4e75-85d1-0b10a07ece8b          55          43         34
#
#     ateLista  desistente  total_subm  totalQuest  subm/quest
# 0         15           0         105          34    3.088235
# 1         15           0          69          34    2.029412
# 2         15           0          80          34    2.352941
# 3         15           0         194          34    5.705882
# 4         15           0         398          34   11.705882
# ..       ...         ...         ...         ...         ...
# 82        15           0         376          34   11.058824
# 83        15           0         222          34    6.529412
# 84        15           0          95          34    2.794118
# 85        15           0          75          34    2.205882
# 86        15           0          98          34    2.882353
#
# [87 rows x 9 columns]

# %%
plt.scatter(df_list4['totalError'].tolist(), 
            df_list4['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
plt.scatter(df_list4['acert_100'].tolist(), 
            df_list4['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
plt.scatter(df_list4['subm/quest'].tolist(), 
            df_list4['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
df_list4['totalError'] = df_list4['totalError'] / df_list4['total_subm']
df_list4['totalAcert'] = df_list4['totalAcert'] / df_list4['total_subm']
df_list4['acert_100'] = df_list4['acert_100'] / df_list4['total_subm']
df_list4
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 0   0343690d-9edd-48cf-be09-6dc1f4b3f61c    0.457143    0.542857   0.504762
# 1   035bbeb6-140b-413c-826d-9f92e36a31ae    0.405797    0.594203   0.492754
# 2   04a9f776-feee-4b63-8127-50270693e39f    0.300000    0.700000   0.537500
# 3   05c35721-051a-43fa-96b7-aeec0d0eafb5    0.541237    0.458763   0.314433
# 4   06bddeab-42f1-428a-88d1-adf096da3432    0.798995    0.201005   0.105528
# ..                                   ...         ...         ...        ...
# 82  e785df2f-1b73-452f-bc30-eea29af9032f    0.720745    0.279255   0.119681
# 83  e8af96e7-0bac-45ff-a498-f22acb1af407    0.729730    0.270270   0.189189
# 84  f4e5c666-288b-4bbf-951b-56fd0fbb7f9f    0.536842    0.463158   0.389474
# 85  f5874924-7ed6-421c-ac14-3c0bccf51c24    0.400000    0.600000   0.466667
# 86  fe56d94c-26d1-4e75-85d1-0b10a07ece8b    0.561224    0.438776   0.346939
#
#     ateLista  desistente  total_subm  totalQuest  subm/quest
# 0         15           0         105          34    3.088235
# 1         15           0          69          34    2.029412
# 2         15           0          80          34    2.352941
# 3         15           0         194          34    5.705882
# 4         15           0         398          34   11.705882
# ..       ...         ...         ...         ...         ...
# 82        15           0         376          34   11.058824
# 83        15           0         222          34    6.529412
# 84        15           0          95          34    2.794118
# 85        15           0          75          34    2.205882
# 86        15           0          98          34    2.882353
#
# [87 rows x 9 columns]

# %%
plt.scatter(df_list4['totalError'].tolist(), 
            df_list4['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
plt.scatter(df_list4['acert_100'].tolist(), 
            df_list4['desistente'].tolist(), 
            marker='o')
plt.show()

# %%
df_list4['teste'] = df_list4['totalError'] * df_list4['subm/quest']
grap4 = df_list4[df_list4['teste']>0]
plt.scatter(grap4['teste'].tolist(), 
            grap4['desistente'].tolist(), 
            marker='o')
plt.show()
print(grap4['teste'].min())
print(grap4['teste'].max())
# Out:
# 0.0588235294117647
# 10.558823529411764

# %%
grap = grap4[grap4['desistente']==1]
#test_ndes = ind[ind['desistente']==0]

teste1 = grap4[grap4['teste']<=grap['teste'].max()]
teste1[teste1['totalError']==teste1['totalError'].max()]
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 79  da131b91-0126-41ca-9e6e-17dad2104ffd     0.84898     0.15102   0.138776
#
#     ateLista  desistente  total_subm  totalQuest  subm/quest  teste
# 79         3           1         245          32     7.65625    6.5

# %%
df_list4['teste'] = df_list4['totalAcert'] * df_list4['subm/quest']
grap4 = df_list4[df_list4['teste']>0]
plt.scatter(grap4['teste'].tolist(), 
            grap4['desistente'].tolist(), 
            marker='o')
plt.show()
print(grap4['teste'].min())
print(grap4['teste'].max())
# Out:
# 0.9599999999999999
# 3.705882352941176

# %%
grap = grap4[grap4['desistente']==1]
#test_ndes = ind[ind['desistente']==0]

teste1 = grap4[grap4['teste']<=grap['teste'].max()]
teste1[teste1['totalError']==teste1['totalError'].max()]
teste1
#2 maior probabilidade de erro // dos 2 maiores em taxa de erro, o que menos de % de 100 perante o acerto
#dos 2 maiores em taxa de erro, o que menos subm/quest
#12/87
# Out:
#                                  user_id  totalError  totalAcert  acert_100  \
# 10  174b3116-31b8-4f19-bf06-2b597f96cc8a    0.574713    0.425287   0.402299
# 16  1eb39a33-8898-4a33-a978-b1db76e94c88    0.414634    0.585366   0.585366
# 32  4f381a38-98c4-404b-b386-4cdda6a06565    0.051282    0.948718   0.923077
# 37  6055380e-fafa-4dcb-b6db-34fcd0843098    0.734375    0.265625   0.242188
# 38  61378206-cf75-4fc0-95dc-43f6e81a788c    0.457143    0.542857   0.485714
# 39  64cc36c5-4fcc-445a-b360-3a25c9783645    0.701031    0.298969   0.288660
# 67  b9240348-c223-4c0d-b75f-09c522952143    0.521127    0.478873   0.478873
# 69  bbf405b0-63d5-4031-9e5c-f4914a92c1dc    0.162791    0.837209   0.813953
# 71  c206e495-e2a7-4fad-8cc1-eed9690dc6dc    0.869565    0.130435   0.130435
# 74  d03cea24-3f4b-4f09-8de3-7b17d604a98e    0.327586    0.672414   0.655172
# 79  da131b91-0126-41ca-9e6e-17dad2104ffd    0.848980    0.151020   0.138776
# 81  e665b54f-9a93-4e52-9e53-73f6e3853d4e    0.442623    0.557377   0.491803
#
#     ateLista  desistente  total_subm  totalQuest  subm/quest     teste
# 10        15           0          87          34    2.558824  1.088235
# 16        15           0          41          25    1.640000  0.960000
# 32        15           0          39          34    1.147059  1.088235
# 37        15           0         128          30    4.266667  1.133333
# 38        15           0          70          34    2.058824  1.117647
# 39        15           0          97          28    3.464286  1.035714
# 67        15           0          71          34    2.088235  1.000000
# 69        15           0          43          34    1.264706  1.058824
# 71        15           0          23           3    7.666667  1.000000
# 74        15           0          58          34    1.705882  1.147059
# 79         3           1         245          32    7.656250  1.156250
# 81        15           0          61          31    1.967742  1.096774
